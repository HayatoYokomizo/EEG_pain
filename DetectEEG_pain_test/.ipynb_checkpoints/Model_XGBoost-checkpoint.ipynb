# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import xgboost as xgb
from scipy import stats
import shap
import seaborn as sns

def calculate_correlations(shap_values, features_df, feature_names, num_classes):
    correlation_df = pd.DataFrame()

    for feature in feature_names:
        correlation_dict = {'feature': feature}

        for i in range(num_classes):
            shap_values_i = shap_values[i][:, features_df.columns.get_loc(feature)]
            feature_values_i = features_df[feature].values

            correlation_coefficient_i = np.corrcoef(shap_values_i, feature_values_i)[0, 1]
            correlation_dict[f'correlation_{i}'] = correlation_coefficient_i

        correlation_df = correlation_df.append(correlation_dict, ignore_index=True)

    return correlation_df

def XGBoost(X, y):
    # データを訓練用とテスト用に分割
    X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    # 訓練データをさらに訓練用と検証用に分割
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=0)

    # モデルのパラメータを設定(CPU)
    params = {
        'objective': 'multi:softmax',
        'eval_metric': 'mlogloss',
        'num_class' : 4,
        'eta': 0.1,
        'max_depth': 4,
        'seed': 0,
        'tree_method': 'gpu_hist',
        'predictor': 'gpu_predictor'
    }
    
    # データをpandas.DataFrame形式で保存
    X_train_df = pd.DataFrame(X_train, columns=column_names)
    y_train_df = pd.DataFrame(y_train, columns=column_names)

    # 訓練データと検証データをXGBoostのDMatrix形式に変換
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)

    # 訓練データと検証データのセットをリストに格納
    evals = [(dtrain, 'train'), (dval, 'eval')]

    # モデルを訓練
    bst = xgb.train(params, dtrain, num_boost_round=10000, evals=evals, early_stopping_rounds=100)

    # テストデータをDMatrix形式に変換
    dtest = xgb.DMatrix(X_test)

    # 訓練データで予測
    y_train_pred = bst.predict(dtrain)

    # テストデータで予測
    y_pred = bst.predict(dtest)

    # 評価
    train_accuracy = accuracy_score(y_train, y_train_pred.round())
    print(f"Training Accuracy: {train_accuracy*100:.2f}%")

    # 評価
    test_accuracy = accuracy_score(y_test, y_pred.round())
    print(f"Test Accuracy: {test_accuracy*100:.2f}%")
        
    return X_train_df, y_train_df, bst

def normalize_per_state(df, start, end):
    scaler = StandardScaler()
    df.iloc[start:end, :] = scaler.fit_transform(df.iloc[start:end, :])
    return df

# %%
# 1秒ごとのデータに分割
n_samples_per_second = 256  # 256Hzのサンプリングレート
total_seconds = 10  # 全体の秒数

# データの読み込み
df = pd.read_csv('DP_all.csv')

""""
# チャンネルごとに正規化
scaler = StandardScaler()
for column in df.columns[:-1]:  # 'State'列を除くすべての列
    df[column] = scaler.fit_transform(df[column].values.reshape(-1, 1))
"""
# Out:
# '"\n# チャンネルごとに正規化\nscaler = StandardScaler()\nfor column in df.columns[:-1]:  # \'State\'列を除くすべての列\n    df[column] = scaler.fit_transform(df[column].values.reshape(-1, 1))\n'

# %%
# Hzごと
# 特徴量と目標変数を抽出する
X = df.drop('Marker', axis=1)  # 'State'以外の列すべてを特徴量とします
y = df['Marker']  # 'State'を目標変数とします

# 列名のリストを定義
column_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']
#XGBoost
X_train_df, y_train_df, bst = XGBoost(X, y)
# Out:
# [0]	train-mlogloss:1.24126	eval-mlogloss:1.25114
# [1]	train-mlogloss:1.12186	eval-mlogloss:1.14207
# [2]	train-mlogloss:1.01897	eval-mlogloss:1.04707
# [3]	train-mlogloss:0.92952	eval-mlogloss:0.96606
# [4]	train-mlogloss:0.85272	eval-mlogloss:0.89447
# [5]	train-mlogloss:0.78452	eval-mlogloss:0.83233
# [6]	train-mlogloss:0.72108	eval-mlogloss:0.77831
# [7]	train-mlogloss:0.66596	eval-mlogloss:0.73140
# [8]	train-mlogloss:0.61875	eval-mlogloss:0.69187
# [9]	train-mlogloss:0.57551	eval-mlogloss:0.65322
# [10]	train-mlogloss:0.53307	eval-mlogloss:0.61760
# [11]	train-mlogloss:0.49517	eval-mlogloss:0.58507
# [12]	train-mlogloss:0.46050	eval-mlogloss:0.55759
# [13]	train-mlogloss:0.42997	eval-mlogloss:0.53068
# [14]	train-mlogloss:0.40197	eval-mlogloss:0.50809
# [15]	train-mlogloss:0.37580	eval-mlogloss:0.48546
# [16]	train-mlogloss:0.35257	eval-mlogloss:0.46637
# [17]	train-mlogloss:0.33073	eval-mlogloss:0.44982
# [18]	train-mlogloss:0.31060	eval-mlogloss:0.43004
# [19]	train-mlogloss:0.29114	eval-mlogloss:0.41614
# [20]	train-mlogloss:0.27654	eval-mlogloss:0.40009
# [21]	train-mlogloss:0.26078	eval-mlogloss:0.39025
# [22]	train-mlogloss:0.24827	eval-mlogloss:0.37712
# [23]	train-mlogloss:0.23413	eval-mlogloss:0.36746
# [24]	train-mlogloss:0.22319	eval-mlogloss:0.35528
# [25]	train-mlogloss:0.21186	eval-mlogloss:0.34682
# [26]	train-mlogloss:0.20058	eval-mlogloss:0.34029
# [27]	train-mlogloss:0.19005	eval-mlogloss:0.33403
# [28]	train-mlogloss:0.18137	eval-mlogloss:0.32620
# [29]	train-mlogloss:0.17226	eval-mlogloss:0.31974
# [30]	train-mlogloss:0.16586	eval-mlogloss:0.31460
# [31]	train-mlogloss:0.16005	eval-mlogloss:0.30922
# [32]	train-mlogloss:0.15293	eval-mlogloss:0.30391
# [33]	train-mlogloss:0.14619	eval-mlogloss:0.29928
# [34]	train-mlogloss:0.13930	eval-mlogloss:0.29399
# [35]	train-mlogloss:0.13471	eval-mlogloss:0.28812
# [36]	train-mlogloss:0.12885	eval-mlogloss:0.28406
# [37]	train-mlogloss:0.12366	eval-mlogloss:0.28005
# [38]	train-mlogloss:0.11915	eval-mlogloss:0.27565
# [39]	train-mlogloss:0.11471	eval-mlogloss:0.27218
# [40]	train-mlogloss:0.11049	eval-mlogloss:0.26939
# [41]	train-mlogloss:0.10721	eval-mlogloss:0.26700
# [42]	train-mlogloss:0.10332	eval-mlogloss:0.26526
# [43]	train-mlogloss:0.10047	eval-mlogloss:0.26240
# [44]	train-mlogloss:0.09765	eval-mlogloss:0.26004
# [45]	train-mlogloss:0.09542	eval-mlogloss:0.25685
# [46]	train-mlogloss:0.09321	eval-mlogloss:0.25457
# [47]	train-mlogloss:0.09073	eval-mlogloss:0.25068
# [48]	train-mlogloss:0.08828	eval-mlogloss:0.24749
# [49]	train-mlogloss:0.08573	eval-mlogloss:0.24400
# [50]	train-mlogloss:0.08315	eval-mlogloss:0.24306
# [51]	train-mlogloss:0.08071	eval-mlogloss:0.24016
# [52]	train-mlogloss:0.07810	eval-mlogloss:0.23947
# [53]	train-mlogloss:0.07606	eval-mlogloss:0.23699
# [54]	train-mlogloss:0.07407	eval-mlogloss:0.23478
# [55]	train-mlogloss:0.07239	eval-mlogloss:0.23484
# [56]	train-mlogloss:0.07084	eval-mlogloss:0.23360
# [57]	train-mlogloss:0.06908	eval-mlogloss:0.23164
# [58]	train-mlogloss:0.06778	eval-mlogloss:0.23281
# [59]	train-mlogloss:0.06566	eval-mlogloss:0.23070
# [60]	train-mlogloss:0.06373	eval-mlogloss:0.22993
# [61]	train-mlogloss:0.06232	eval-mlogloss:0.22963
# [62]	train-mlogloss:0.06090	eval-mlogloss:0.22734
# [63]	train-mlogloss:0.06000	eval-mlogloss:0.22605
# [64]	train-mlogloss:0.05888	eval-mlogloss:0.22598
# [65]	train-mlogloss:0.05749	eval-mlogloss:0.22443
# [66]	train-mlogloss:0.05650	eval-mlogloss:0.22604
# [67]	train-mlogloss:0.05490	eval-mlogloss:0.22526
# [68]	train-mlogloss:0.05364	eval-mlogloss:0.22440
# [69]	train-mlogloss:0.05286	eval-mlogloss:0.22599
# [70]	train-mlogloss:0.05159	eval-mlogloss:0.22444
# [71]	train-mlogloss:0.05014	eval-mlogloss:0.22508
# [72]	train-mlogloss:0.04883	eval-mlogloss:0.22643
# [73]	train-mlogloss:0.04742	eval-mlogloss:0.22622
# [74]	train-mlogloss:0.04672	eval-mlogloss:0.22575
# [75]	train-mlogloss:0.04504	eval-mlogloss:0.22691
# [76]	train-mlogloss:0.04386	eval-mlogloss:0.22683
# [77]	train-mlogloss:0.04273	eval-mlogloss:0.22364
# [78]	train-mlogloss:0.04217	eval-mlogloss:0.22505
# [79]	train-mlogloss:0.04141	eval-mlogloss:0.22585
# [80]	train-mlogloss:0.04013	eval-mlogloss:0.22635
# [81]	train-mlogloss:0.03965	eval-mlogloss:0.22599
# [82]	train-mlogloss:0.03860	eval-mlogloss:0.22405
# [83]	train-mlogloss:0.03804	eval-mlogloss:0.22416
# [84]	train-mlogloss:0.03716	eval-mlogloss:0.22118
# [85]	train-mlogloss:0.03642	eval-mlogloss:0.22083
# [86]	train-mlogloss:0.03565	eval-mlogloss:0.22146
# [87]	train-mlogloss:0.03491	eval-mlogloss:0.22127
# [88]	train-mlogloss:0.03448	eval-mlogloss:0.22233
# [89]	train-mlogloss:0.03361	eval-mlogloss:0.22283
# [90]	train-mlogloss:0.03297	eval-mlogloss:0.22272
# [91]	train-mlogloss:0.03234	eval-mlogloss:0.22140
# [92]	train-mlogloss:0.03174	eval-mlogloss:0.22243
# [93]	train-mlogloss:0.03128	eval-mlogloss:0.22172
# [94]	train-mlogloss:0.03066	eval-mlogloss:0.22029
# [95]	train-mlogloss:0.03011	eval-mlogloss:0.22022
# [96]	train-mlogloss:0.02954	eval-mlogloss:0.22066
# [97]	train-mlogloss:0.02884	eval-mlogloss:0.21859
# [98]	train-mlogloss:0.02835	eval-mlogloss:0.21836
# [99]	train-mlogloss:0.02790	eval-mlogloss:0.21995
# [100]	train-mlogloss:0.02770	eval-mlogloss:0.22114
# [101]	train-mlogloss:0.02728	eval-mlogloss:0.22038
# [102]	train-mlogloss:0.02677	eval-mlogloss:0.21966
# [103]	train-mlogloss:0.02617	eval-mlogloss:0.21788
# [104]	train-mlogloss:0.02583	eval-mlogloss:0.21764
# [105]	train-mlogloss:0.02544	eval-mlogloss:0.21743
# [106]	train-mlogloss:0.02495	eval-mlogloss:0.21737
# [107]	train-mlogloss:0.02458	eval-mlogloss:0.21690
# [108]	train-mlogloss:0.02410	eval-mlogloss:0.21526
# [109]	train-mlogloss:0.02374	eval-mlogloss:0.21594
# [110]	train-mlogloss:0.02344	eval-mlogloss:0.21612
# [111]	train-mlogloss:0.02298	eval-mlogloss:0.21555
# [112]	train-mlogloss:0.02265	eval-mlogloss:0.21588
# [113]	train-mlogloss:0.02226	eval-mlogloss:0.21542
# [114]	train-mlogloss:0.02202	eval-mlogloss:0.21573
# [115]	train-mlogloss:0.02165	eval-mlogloss:0.21489
# [116]	train-mlogloss:0.02143	eval-mlogloss:0.21468
# [117]	train-mlogloss:0.02109	eval-mlogloss:0.21540
# [118]	train-mlogloss:0.02094	eval-mlogloss:0.21557
# [119]	train-mlogloss:0.02066	eval-mlogloss:0.21624
# [120]	train-mlogloss:0.02036	eval-mlogloss:0.21540
# [121]	train-mlogloss:0.02011	eval-mlogloss:0.21584
# [122]	train-mlogloss:0.01981	eval-mlogloss:0.21642
# [123]	train-mlogloss:0.01953	eval-mlogloss:0.21552
# [124]	train-mlogloss:0.01928	eval-mlogloss:0.21489
# [125]	train-mlogloss:0.01904	eval-mlogloss:0.21570
# [126]	train-mlogloss:0.01872	eval-mlogloss:0.21568
# [127]	train-mlogloss:0.01844	eval-mlogloss:0.21672
# [128]	train-mlogloss:0.01817	eval-mlogloss:0.21625
# [129]	train-mlogloss:0.01792	eval-mlogloss:0.21740
# [130]	train-mlogloss:0.01773	eval-mlogloss:0.21806
# [131]	train-mlogloss:0.01753	eval-mlogloss:0.21776
# [132]	train-mlogloss:0.01736	eval-mlogloss:0.21896
# [133]	train-mlogloss:0.01713	eval-mlogloss:0.21874
# [134]	train-mlogloss:0.01691	eval-mlogloss:0.21786
# [135]	train-mlogloss:0.01673	eval-mlogloss:0.21859
# [136]	train-mlogloss:0.01653	eval-mlogloss:0.21918
# [137]	train-mlogloss:0.01634	eval-mlogloss:0.21901
# [138]	train-mlogloss:0.01613	eval-mlogloss:0.21965
# [139]	train-mlogloss:0.01597	eval-mlogloss:0.21932
# [140]	train-mlogloss:0.01582	eval-mlogloss:0.21964
# [141]	train-mlogloss:0.01564	eval-mlogloss:0.21954
# [142]	train-mlogloss:0.01546	eval-mlogloss:0.21882
# [143]	train-mlogloss:0.01531	eval-mlogloss:0.21973
# [144]	train-mlogloss:0.01516	eval-mlogloss:0.21986
# [145]	train-mlogloss:0.01499	eval-mlogloss:0.21925
# [146]	train-mlogloss:0.01482	eval-mlogloss:0.22002
# [147]	train-mlogloss:0.01464	eval-mlogloss:0.22048
# [148]	train-mlogloss:0.01450	eval-mlogloss:0.21966
# [149]	train-mlogloss:0.01438	eval-mlogloss:0.22035
# [150]	train-mlogloss:0.01422	eval-mlogloss:0.22113
# [151]	train-mlogloss:0.01411	eval-mlogloss:0.22167
# [152]	train-mlogloss:0.01395	eval-mlogloss:0.22243
# [153]	train-mlogloss:0.01382	eval-mlogloss:0.22161
# [154]	train-mlogloss:0.01370	eval-mlogloss:0.22133
# [155]	train-mlogloss:0.01358	eval-mlogloss:0.22150
# [156]	train-mlogloss:0.01347	eval-mlogloss:0.22076
# [157]	train-mlogloss:0.01334	eval-mlogloss:0.22030
# [158]	train-mlogloss:0.01322	eval-mlogloss:0.22069
# [159]	train-mlogloss:0.01312	eval-mlogloss:0.22097
# [160]	train-mlogloss:0.01300	eval-mlogloss:0.22152
# [161]	train-mlogloss:0.01290	eval-mlogloss:0.22129
# [162]	train-mlogloss:0.01280	eval-mlogloss:0.22075
# [163]	train-mlogloss:0.01271	eval-mlogloss:0.22061
# [164]	train-mlogloss:0.01260	eval-mlogloss:0.22109
# [165]	train-mlogloss:0.01249	eval-mlogloss:0.22079
# [166]	train-mlogloss:0.01238	eval-mlogloss:0.22072
# [167]	train-mlogloss:0.01230	eval-mlogloss:0.22066
# [168]	train-mlogloss:0.01221	eval-mlogloss:0.22077
# [169]	train-mlogloss:0.01209	eval-mlogloss:0.22095
# [170]	train-mlogloss:0.01199	eval-mlogloss:0.22119
# [171]	train-mlogloss:0.01190	eval-mlogloss:0.22012
# [172]	train-mlogloss:0.01181	eval-mlogloss:0.22059
# [173]	train-mlogloss:0.01173	eval-mlogloss:0.22033
# [174]	train-mlogloss:0.01163	eval-mlogloss:0.22029
# [175]	train-mlogloss:0.01154	eval-mlogloss:0.21963
# [176]	train-mlogloss:0.01146	eval-mlogloss:0.21928
# [177]	train-mlogloss:0.01136	eval-mlogloss:0.21938
# [178]	train-mlogloss:0.01128	eval-mlogloss:0.21956
# [179]	train-mlogloss:0.01121	eval-mlogloss:0.22004
# [180]	train-mlogloss:0.01114	eval-mlogloss:0.22024
# [181]	train-mlogloss:0.01106	eval-mlogloss:0.22045
# [182]	train-mlogloss:0.01098	eval-mlogloss:0.21971
# [183]	train-mlogloss:0.01093	eval-mlogloss:0.21993
# [184]	train-mlogloss:0.01086	eval-mlogloss:0.21983
# [185]	train-mlogloss:0.01079	eval-mlogloss:0.21999
# [186]	train-mlogloss:0.01072	eval-mlogloss:0.21971
# [187]	train-mlogloss:0.01066	eval-mlogloss:0.21980
# [188]	train-mlogloss:0.01059	eval-mlogloss:0.21937
# [189]	train-mlogloss:0.01051	eval-mlogloss:0.21913
# [190]	train-mlogloss:0.01044	eval-mlogloss:0.21886
# [191]	train-mlogloss:0.01038	eval-mlogloss:0.21874
# [192]	train-mlogloss:0.01032	eval-mlogloss:0.21885
# [193]	train-mlogloss:0.01026	eval-mlogloss:0.21921
# [194]	train-mlogloss:0.01020	eval-mlogloss:0.21896
# [195]	train-mlogloss:0.01014	eval-mlogloss:0.21873
# [196]	train-mlogloss:0.01007	eval-mlogloss:0.21843
# [197]	train-mlogloss:0.01001	eval-mlogloss:0.21814
# [198]	train-mlogloss:0.00995	eval-mlogloss:0.21843
# [199]	train-mlogloss:0.00990	eval-mlogloss:0.21790
# [200]	train-mlogloss:0.00985	eval-mlogloss:0.21817
# [201]	train-mlogloss:0.00980	eval-mlogloss:0.21824
# [202]	train-mlogloss:0.00975	eval-mlogloss:0.21882
# [203]	train-mlogloss:0.00969	eval-mlogloss:0.21914
# [204]	train-mlogloss:0.00964	eval-mlogloss:0.21953
# [205]	train-mlogloss:0.00958	eval-mlogloss:0.21983
# [206]	train-mlogloss:0.00952	eval-mlogloss:0.21918
# [207]	train-mlogloss:0.00949	eval-mlogloss:0.21916
# [208]	train-mlogloss:0.00943	eval-mlogloss:0.21891
# [209]	train-mlogloss:0.00939	eval-mlogloss:0.21895
# [210]	train-mlogloss:0.00934	eval-mlogloss:0.21922
# [211]	train-mlogloss:0.00929	eval-mlogloss:0.21934
# [212]	train-mlogloss:0.00924	eval-mlogloss:0.21965
# [213]	train-mlogloss:0.00920	eval-mlogloss:0.21951
# [214]	train-mlogloss:0.00915	eval-mlogloss:0.21933
# [215]	train-mlogloss:0.00911	eval-mlogloss:0.21904
# Training Accuracy: 100.00%
# Test Accuracy: 93.51%

# %%
explainer = shap.TreeExplainer(bst)
shap_values = explainer.shap_values(X_train_df,y_train_df)

shap.summary_plot(shap_values, X_train_df)

# %%
# SHAP値をプロット
shap.summary_plot(shap_values[0], X_train_df, max_display=X_train_df.shape[1])
#各ｃｈの電圧値とSHAP値の線形グラフ
shap.dependence_plot("O2", shap_values[0], X_train_df)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
# SHAP値をプロット
shap.summary_plot(shap_values[1], X_train_df, max_display=X_train_df.shape[1])
#各ｃｈの電圧値とSHAP値の線形グラフ
shap.dependence_plot("O2", shap_values[1], X_train_df)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
num_classes = 2  # クラス数を設定
correlation_df = calculate_correlations(shap_values, X_train_df, column_names, num_classes).T
correlation_df
# Out:
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                      0         1         2         3         4         5   \
# feature             AF3        F7        F3       FC5        T7        P7
# correlation_0  0.672302  0.937551 -0.855336 -0.341507  0.711494  0.214002
# correlation_1 -0.628928 -0.933007  0.807666  0.565123 -0.667718 -0.351313
#
#                      6         7         8         9         10        11  \
# feature              O1        O2        P8        T8       FC6        F4
# correlation_0 -0.752515 -0.881781 -0.702777  0.905807   0.31938  0.545972
# correlation_1  0.787115  0.908341  0.758993 -0.871075  0.009125 -0.650547
#
#                      12        13
# feature              F8       AF4
# correlation_0 -0.845155  0.780638
# correlation_1  0.787257 -0.337969

# %% [raw]
# """
# #１秒ごとに分割
# # ラベルの作成（5秒閉じ、5秒開け）
# labels_close = [0] * 5 *64
# labels_open = [1] * 5 * 64
# labels = labels_close + labels_open
#
# #labels = df.iloc[:, -1]
#
# #14chデータ
# n_samples_per_second = 4
# total_seconds = 10  # 全体の秒数
# #total_seconds = 3242  # 全体の秒数
#
# # データとラベルを1秒ごとに分割
# #X = np.array([df.iloc[i*n_samples_per_second:(i+1)*n_samples_per_second, :-1].values for i in range(total_seconds)])
#
# X = np.array([df.iloc[i*n_samples_per_second:(i+1)*n_samples_per_second, :-1].values for i in range(total_seconds*64)])
# #labels = np.array([stats.mode(y[i*n_samples_per_second:(i+1)*n_samples_per_second])[0][0] for i in range(total_seconds*64)])
#
#
# # 1秒ごとのデータの平均を取得
# X = X.mean(axis=1)
#
# #XGBoost
# XGBoost(X, labels)
#
# #plot
# #plot_importance(raw, model1)
#
# """
