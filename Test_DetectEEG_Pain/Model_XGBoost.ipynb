# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import xgboost as xgb
from scipy import stats
import shap
import seaborn as sns

def calculate_correlations(shap_values, features_df, feature_names, num_classes):
    correlation_df = pd.DataFrame()

    for feature in feature_names:
        correlation_dict = {'feature': feature}

        for i in range(num_classes):
            shap_values_i = shap_values[i][:, features_df.columns.get_loc(feature)]
            feature_values_i = features_df[feature].values

            correlation_coefficient_i = np.corrcoef(shap_values_i, feature_values_i)[0, 1]
            correlation_dict[f'correlation_{i}'] = correlation_coefficient_i

        correlation_df = correlation_df.append(correlation_dict, ignore_index=True)

    return correlation_df

def XGBoost(X, y):
    # データを訓練用とテスト用に分割
    X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    # 訓練データをさらに訓練用と検証用に分割
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=0)

    # モデルのパラメータを設定(CPU)
    params = {
        'objective': 'multi:softmax',
        'eval_metric': 'mlogloss',
        'num_class' : 2,
        'eta': 0.1,
        'max_depth': 4,
        'seed': 0,
        'tree_method': 'gpu_hist',
        'predictor': 'gpu_predictor'
    }
    
    # データをpandas.DataFrame形式で保存
    X_train_df = pd.DataFrame(X_train, columns=column_names)
    y_train_df = pd.DataFrame(y_train, columns=column_names)

    # 訓練データと検証データをXGBoostのDMatrix形式に変換
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)

    # 訓練データと検証データのセットをリストに格納
    evals = [(dtrain, 'train'), (dval, 'eval')]

    # モデルを訓練
    bst = xgb.train(params, dtrain, num_boost_round=10000, evals=evals, early_stopping_rounds=100)

    # テストデータをDMatrix形式に変換
    dtest = xgb.DMatrix(X_test)

    # 訓練データで予測
    y_train_pred = bst.predict(dtrain)

    # テストデータで予測
    y_pred = bst.predict(dtest)

    # 評価
    train_accuracy = accuracy_score(y_train, y_train_pred.round())
    print(f"Training Accuracy: {train_accuracy*100:.2f}%")

    # 評価
    test_accuracy = accuracy_score(y_test, y_pred.round())
    print(f"Test Accuracy: {test_accuracy*100:.2f}%")
        
    return X_train_df, y_train_df, bst

def normalize_per_state(df, start, end):
    scaler = StandardScaler()
    df.iloc[start:end, :] = scaler.fit_transform(df.iloc[start:end, :])
    return df

# %%
# 1秒ごとのデータに分割
n_samples_per_second = 256  # 256Hzのサンプリングレート
total_seconds = 10  # 全体の秒数

# データの読み込み
df = pd.read_csv('DP_all.csv')

"""
# チャンネルごとに正規化
scaler = StandardScaler()
for column in df.columns[:-1]:  # 'State'列を除くすべての列
    df[column] = scaler.fit_transform(df[column].values.reshape(-1, 1))
"""
# Out:
# "\n# チャンネルごとに正規化\nscaler = StandardScaler()\nfor column in df.columns[:-1]:  # 'State'列を除くすべての列\n    df[column] = scaler.fit_transform(df[column].values.reshape(-1, 1))\n"

# %%
# Hzごと
# 特徴量と目標変数を抽出する
X = df.drop('Marker', axis=1)  # 'State'以外の列すべてを特徴量とします
y = df['Marker']  # 'State'を目標変数とします

# 列名のリストを定義
column_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']
#XGBoost
X_train_df, y_train_df, bst = XGBoost(X, y)
# Out:
# [0]	train-mlogloss:0.63142	eval-mlogloss:0.63887
# [1]	train-mlogloss:0.58247	eval-mlogloss:0.59915
# [2]	train-mlogloss:0.53633	eval-mlogloss:0.56356
# [3]	train-mlogloss:0.50091	eval-mlogloss:0.53167
# [4]	train-mlogloss:0.46519	eval-mlogloss:0.50436
# [5]	train-mlogloss:0.43639	eval-mlogloss:0.48301
# [6]	train-mlogloss:0.41095	eval-mlogloss:0.46506
# [7]	train-mlogloss:0.38178	eval-mlogloss:0.44501
# [8]	train-mlogloss:0.36038	eval-mlogloss:0.42756
# [9]	train-mlogloss:0.33725	eval-mlogloss:0.41258
# [10]	train-mlogloss:0.32074	eval-mlogloss:0.39858
# [11]	train-mlogloss:0.30438	eval-mlogloss:0.38752
# [12]	train-mlogloss:0.28705	eval-mlogloss:0.37609
# [13]	train-mlogloss:0.27283	eval-mlogloss:0.36534
# [14]	train-mlogloss:0.26038	eval-mlogloss:0.35623
# [15]	train-mlogloss:0.24257	eval-mlogloss:0.34573
# [16]	train-mlogloss:0.23295	eval-mlogloss:0.33923
# [17]	train-mlogloss:0.21864	eval-mlogloss:0.32922
# [18]	train-mlogloss:0.20657	eval-mlogloss:0.32348
# [19]	train-mlogloss:0.19978	eval-mlogloss:0.31746
# [20]	train-mlogloss:0.18876	eval-mlogloss:0.31037
# [21]	train-mlogloss:0.17844	eval-mlogloss:0.30585
# [22]	train-mlogloss:0.17067	eval-mlogloss:0.30133
# [23]	train-mlogloss:0.16453	eval-mlogloss:0.29418
# [24]	train-mlogloss:0.15731	eval-mlogloss:0.29249
# [25]	train-mlogloss:0.15137	eval-mlogloss:0.28862
# [26]	train-mlogloss:0.14327	eval-mlogloss:0.28489
# [27]	train-mlogloss:0.13871	eval-mlogloss:0.28168
# [28]	train-mlogloss:0.13497	eval-mlogloss:0.28053
# [29]	train-mlogloss:0.12795	eval-mlogloss:0.27654
# [30]	train-mlogloss:0.12483	eval-mlogloss:0.26968
# [31]	train-mlogloss:0.11913	eval-mlogloss:0.26711
# [32]	train-mlogloss:0.11560	eval-mlogloss:0.26589
# [33]	train-mlogloss:0.11171	eval-mlogloss:0.26123
# [34]	train-mlogloss:0.10893	eval-mlogloss:0.26003
# [35]	train-mlogloss:0.10381	eval-mlogloss:0.25421
# [36]	train-mlogloss:0.10020	eval-mlogloss:0.25337
# [37]	train-mlogloss:0.09725	eval-mlogloss:0.25112
# [38]	train-mlogloss:0.09412	eval-mlogloss:0.24852
# [39]	train-mlogloss:0.09111	eval-mlogloss:0.24769
# [40]	train-mlogloss:0.08673	eval-mlogloss:0.24671
# [41]	train-mlogloss:0.08470	eval-mlogloss:0.24496
# [42]	train-mlogloss:0.08335	eval-mlogloss:0.24364
# [43]	train-mlogloss:0.07994	eval-mlogloss:0.24284
# [44]	train-mlogloss:0.07749	eval-mlogloss:0.24256
# [45]	train-mlogloss:0.07573	eval-mlogloss:0.24111
# [46]	train-mlogloss:0.07398	eval-mlogloss:0.23958
# [47]	train-mlogloss:0.07194	eval-mlogloss:0.23939
# [48]	train-mlogloss:0.07013	eval-mlogloss:0.23772
# [49]	train-mlogloss:0.06835	eval-mlogloss:0.23397
# [50]	train-mlogloss:0.06663	eval-mlogloss:0.23389
# [51]	train-mlogloss:0.06506	eval-mlogloss:0.22917
# [52]	train-mlogloss:0.06354	eval-mlogloss:0.22957
# [53]	train-mlogloss:0.06099	eval-mlogloss:0.22932
# [54]	train-mlogloss:0.06024	eval-mlogloss:0.23078
# [55]	train-mlogloss:0.05867	eval-mlogloss:0.22846
# [56]	train-mlogloss:0.05799	eval-mlogloss:0.23053
# [57]	train-mlogloss:0.05679	eval-mlogloss:0.22836
# [58]	train-mlogloss:0.05564	eval-mlogloss:0.22820
# [59]	train-mlogloss:0.05444	eval-mlogloss:0.22408
# [60]	train-mlogloss:0.05369	eval-mlogloss:0.22582
# [61]	train-mlogloss:0.05305	eval-mlogloss:0.22637
# [62]	train-mlogloss:0.05237	eval-mlogloss:0.22621
# [63]	train-mlogloss:0.05165	eval-mlogloss:0.22653
# [64]	train-mlogloss:0.05109	eval-mlogloss:0.22660
# [65]	train-mlogloss:0.05060	eval-mlogloss:0.22896
# [66]	train-mlogloss:0.04936	eval-mlogloss:0.22728
# [67]	train-mlogloss:0.04779	eval-mlogloss:0.22720
# [68]	train-mlogloss:0.04706	eval-mlogloss:0.22928
# [69]	train-mlogloss:0.04578	eval-mlogloss:0.22895
# [70]	train-mlogloss:0.04529	eval-mlogloss:0.23066
# [71]	train-mlogloss:0.04398	eval-mlogloss:0.23045
# [72]	train-mlogloss:0.04286	eval-mlogloss:0.22914
# [73]	train-mlogloss:0.04160	eval-mlogloss:0.22882
# [74]	train-mlogloss:0.04126	eval-mlogloss:0.23010
# [75]	train-mlogloss:0.04056	eval-mlogloss:0.22980
# [76]	train-mlogloss:0.04017	eval-mlogloss:0.23067
# [77]	train-mlogloss:0.03945	eval-mlogloss:0.22913
# [78]	train-mlogloss:0.03845	eval-mlogloss:0.22859
# [79]	train-mlogloss:0.03739	eval-mlogloss:0.22912
# [80]	train-mlogloss:0.03657	eval-mlogloss:0.22838
# [81]	train-mlogloss:0.03565	eval-mlogloss:0.22941
# [82]	train-mlogloss:0.03483	eval-mlogloss:0.22956
# [83]	train-mlogloss:0.03445	eval-mlogloss:0.23089
# [84]	train-mlogloss:0.03385	eval-mlogloss:0.23114
# [85]	train-mlogloss:0.03351	eval-mlogloss:0.23048
# [86]	train-mlogloss:0.03245	eval-mlogloss:0.22763
# [87]	train-mlogloss:0.03183	eval-mlogloss:0.22873
# [88]	train-mlogloss:0.03153	eval-mlogloss:0.22970
# [89]	train-mlogloss:0.03112	eval-mlogloss:0.22865
# [90]	train-mlogloss:0.03019	eval-mlogloss:0.22658
# [91]	train-mlogloss:0.02966	eval-mlogloss:0.22755
# [92]	train-mlogloss:0.02892	eval-mlogloss:0.23041
# [93]	train-mlogloss:0.02816	eval-mlogloss:0.22695
# [94]	train-mlogloss:0.02769	eval-mlogloss:0.22728
# [95]	train-mlogloss:0.02731	eval-mlogloss:0.22708
# [96]	train-mlogloss:0.02706	eval-mlogloss:0.22916
# [97]	train-mlogloss:0.02660	eval-mlogloss:0.22846
# [98]	train-mlogloss:0.02622	eval-mlogloss:0.22986
# [99]	train-mlogloss:0.02580	eval-mlogloss:0.23033
# [100]	train-mlogloss:0.02532	eval-mlogloss:0.23122
# [101]	train-mlogloss:0.02497	eval-mlogloss:0.23078
# [102]	train-mlogloss:0.02465	eval-mlogloss:0.23029
# [103]	train-mlogloss:0.02422	eval-mlogloss:0.22994
# [104]	train-mlogloss:0.02395	eval-mlogloss:0.22890
# [105]	train-mlogloss:0.02373	eval-mlogloss:0.22911
# [106]	train-mlogloss:0.02343	eval-mlogloss:0.22808
# [107]	train-mlogloss:0.02296	eval-mlogloss:0.22773
# [108]	train-mlogloss:0.02270	eval-mlogloss:0.22844
# [109]	train-mlogloss:0.02227	eval-mlogloss:0.22818
# [110]	train-mlogloss:0.02205	eval-mlogloss:0.22879
# [111]	train-mlogloss:0.02169	eval-mlogloss:0.22913
# [112]	train-mlogloss:0.02126	eval-mlogloss:0.23082
# [113]	train-mlogloss:0.02107	eval-mlogloss:0.23089
# [114]	train-mlogloss:0.02083	eval-mlogloss:0.23145
# [115]	train-mlogloss:0.02048	eval-mlogloss:0.22938
# [116]	train-mlogloss:0.02021	eval-mlogloss:0.22899
# [117]	train-mlogloss:0.01992	eval-mlogloss:0.22902
# [118]	train-mlogloss:0.01961	eval-mlogloss:0.23119
# [119]	train-mlogloss:0.01933	eval-mlogloss:0.23182
# [120]	train-mlogloss:0.01916	eval-mlogloss:0.23201
# [121]	train-mlogloss:0.01888	eval-mlogloss:0.23209
# [122]	train-mlogloss:0.01855	eval-mlogloss:0.23305
# [123]	train-mlogloss:0.01825	eval-mlogloss:0.23513
# [124]	train-mlogloss:0.01800	eval-mlogloss:0.23612
# [125]	train-mlogloss:0.01779	eval-mlogloss:0.23633
# [126]	train-mlogloss:0.01748	eval-mlogloss:0.23393
# [127]	train-mlogloss:0.01717	eval-mlogloss:0.23166
# [128]	train-mlogloss:0.01690	eval-mlogloss:0.23010
# [129]	train-mlogloss:0.01660	eval-mlogloss:0.22950
# [130]	train-mlogloss:0.01642	eval-mlogloss:0.22854
# [131]	train-mlogloss:0.01618	eval-mlogloss:0.23010
# [132]	train-mlogloss:0.01598	eval-mlogloss:0.23101
# [133]	train-mlogloss:0.01577	eval-mlogloss:0.23238
# [134]	train-mlogloss:0.01562	eval-mlogloss:0.23263
# [135]	train-mlogloss:0.01545	eval-mlogloss:0.23344
# [136]	train-mlogloss:0.01523	eval-mlogloss:0.23329
# [137]	train-mlogloss:0.01512	eval-mlogloss:0.23299
# [138]	train-mlogloss:0.01497	eval-mlogloss:0.23380
# [139]	train-mlogloss:0.01478	eval-mlogloss:0.23582
# [140]	train-mlogloss:0.01461	eval-mlogloss:0.23493
# [141]	train-mlogloss:0.01443	eval-mlogloss:0.23473
# [142]	train-mlogloss:0.01426	eval-mlogloss:0.23552
# [143]	train-mlogloss:0.01409	eval-mlogloss:0.23539
# [144]	train-mlogloss:0.01395	eval-mlogloss:0.23541
# [145]	train-mlogloss:0.01381	eval-mlogloss:0.23608
# [146]	train-mlogloss:0.01365	eval-mlogloss:0.23721
# [147]	train-mlogloss:0.01353	eval-mlogloss:0.23791
# [148]	train-mlogloss:0.01341	eval-mlogloss:0.23726
# [149]	train-mlogloss:0.01329	eval-mlogloss:0.23757
# [150]	train-mlogloss:0.01316	eval-mlogloss:0.23716
# [151]	train-mlogloss:0.01306	eval-mlogloss:0.23763
# [152]	train-mlogloss:0.01295	eval-mlogloss:0.23713
# [153]	train-mlogloss:0.01283	eval-mlogloss:0.23656
# [154]	train-mlogloss:0.01268	eval-mlogloss:0.23590
# [155]	train-mlogloss:0.01258	eval-mlogloss:0.23470
# [156]	train-mlogloss:0.01248	eval-mlogloss:0.23449
# [157]	train-mlogloss:0.01235	eval-mlogloss:0.23389
# [158]	train-mlogloss:0.01228	eval-mlogloss:0.23360
# Training Accuracy: 100.00%
# Test Accuracy: 94.81%

# %%
explainer = shap.TreeExplainer(bst)
shap_values = explainer.shap_values(X_train_df,y_train_df)

shap.summary_plot(shap_values, X_train_df)

# %%
# SHAP値をプロット
shap.summary_plot(shap_values[0], X_train_df, max_display=X_train_df.shape[1])
#各ｃｈの電圧値とSHAP値の線形グラフ
shap.dependence_plot("O2", shap_values[0], X_train_df)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
# SHAP値をプロット
shap.summary_plot(shap_values[1], X_train_df, max_display=X_train_df.shape[1])
#各ｃｈの電圧値とSHAP値の線形グラフ
shap.dependence_plot("O2", shap_values[1], X_train_df)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
num_classes = 2  # クラス数を設定
correlation_df = calculate_correlations(shap_values, X_train_df, column_names, num_classes).T
correlation_df
# Out:
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                      0         1         2         3         4         5   \
# feature             AF3        F7        F3       FC5        T7        P7
# correlation_0  0.593271  0.938342 -0.850133 -0.368959  0.734139  0.104765
# correlation_1 -0.593271 -0.938342  0.850133  0.368959 -0.734139 -0.104765
#
#                      6         7         8        9         10        11  \
# feature              O1        O2        P8       T8       FC6        F4
# correlation_0 -0.806387 -0.876396 -0.697486  0.91898  0.063467  0.576935
# correlation_1  0.806387  0.876396  0.697486 -0.91898 -0.063467 -0.576935
#
#                      12        13
# feature              F8       AF4
# correlation_0 -0.795737  0.503075
# correlation_1  0.795737 -0.503075

# %% [raw]
# """
# #１秒ごとに分割
# # ラベルの作成（5秒閉じ、5秒開け）
# labels_close = [0] * 5 *64
# labels_open = [1] * 5 * 64
# labels = labels_close + labels_open
#
# #labels = df.iloc[:, -1]
#
# #14chデータ
# n_samples_per_second = 4
# total_seconds = 10  # 全体の秒数
# #total_seconds = 3242  # 全体の秒数
#
# # データとラベルを1秒ごとに分割
# #X = np.array([df.iloc[i*n_samples_per_second:(i+1)*n_samples_per_second, :-1].values for i in range(total_seconds)])
#
# X = np.array([df.iloc[i*n_samples_per_second:(i+1)*n_samples_per_second, :-1].values for i in range(total_seconds*64)])
# #labels = np.array([stats.mode(y[i*n_samples_per_second:(i+1)*n_samples_per_second])[0][0] for i in range(total_seconds*64)])
#
#
# # 1秒ごとのデータの平均を取得
# X = X.mean(axis=1)
#
# #XGBoost
# XGBoost(X, labels)
#
# #plot
# #plot_importance(raw, model1)
#
# """
