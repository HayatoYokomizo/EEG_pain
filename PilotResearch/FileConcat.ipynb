# %%
import glob
import pandas as pd

# %%
file = glob.glob("ReDate/*")

# %%
file.sort()

# %%
file
# Out:
# ['ReDate\\PilotResearch_LF.csv',
#  'ReDate\\PilotResearch_LH.csv',
#  'ReDate\\PilotResearch_RF.csv',
#  'ReDate\\PilotResearch_RH.csv',
#  'ReDate\\PilotResearch_U.csv']

# %%
df = pd.read_csv(file[0]).drop(['Timestamp'],axis=1)
df["Label"] = [1 for i in range(len(df))]

# %%
df
# Out:
#          Cz      Fz      Fp1       F3      C1      C3      T7       C5  \
# 0    74.560   8.735 -184.260 -139.049 -20.467  43.292 -17.302 -113.437
# 1    60.653  -2.544 -200.470 -154.792 -27.619  29.416 -49.048 -121.520
# 2    43.687 -20.985 -224.348 -165.396 -36.300  16.067 -42.851 -132.669
# 3    44.155 -18.915 -209.779 -156.009 -38.826  14.001 -35.123 -131.000
# 4    51.796  -5.576 -179.343 -146.119 -42.373  16.549 -58.654 -124.209
# ..      ...     ...      ...      ...     ...     ...     ...      ...
# 641 -67.218 -62.199 -158.473  -24.786 -38.882 -35.409 -53.209  -23.265
# 642 -62.540 -55.989 -141.921  -15.540 -37.307 -33.836 -20.368  -20.168
# 643 -51.719 -47.736 -133.582   -5.790 -32.659 -28.680 -10.101  -16.561
# 644 -52.692 -47.176 -138.059  -16.031 -28.527 -28.139 -25.461  -19.106
# 645 -62.373 -53.789 -140.995  -30.359 -33.110 -30.160 -16.214  -27.284
#
#          CP5     CP3  ...     CP2     CP4     CP6      C6      T8      C4  \
# 0   -144.059   3.422  ...  42.167  48.239  -6.887 -27.829 -25.069 -44.250
# 1   -152.624 -12.463  ...  28.292  31.285 -19.688 -47.781 -30.167 -61.625
# 2   -158.619 -21.672  ...  19.555  23.569 -27.353 -57.979 -42.944 -75.395
# 3   -160.510 -22.163  ...  20.560  26.107 -22.202 -51.261 -44.951 -66.611
# 4   -157.276 -22.140  ...  25.150  29.155 -18.594 -44.550 -39.270 -59.372
# ..       ...     ...  ...     ...     ...     ...     ...     ...     ...
# 641  -43.437 -45.194  ... -54.668 -54.572 -57.653 -77.876 -60.233 -74.873
# 642  -31.610 -39.514  ... -51.027 -50.419 -55.546 -71.651 -55.562 -75.310
# 643  -26.968 -32.814  ... -41.242 -41.660 -46.781 -69.018 -47.822 -63.964
# 644  -32.576 -32.269  ... -40.176 -39.569 -48.784 -67.412 -54.434 -59.802
# 645  -36.642 -36.848  ... -46.796 -42.091 -56.419 -65.295 -68.212 -68.451
#
#          C2       F4      Fp2  Label
# 0    48.242 -111.996  -91.069      1
# 1    29.751 -123.155 -123.253      1
# 2    20.500 -126.618 -145.159      1
# 3    27.139 -113.171 -112.226      1
# 4    27.625  -98.201  -79.326      1
# ..      ...      ...      ...    ...
# 641 -43.253  -94.958  -89.118      1
# 642 -38.599  -89.740  -90.566      1
# 643 -32.413  -71.719  -92.525      1
# 644 -31.356  -71.135  -90.895      1
# 645 -35.423  -84.897  -94.391      1
#
# [646 rows x 30 columns]

# %%
df_all = pd.DataFrame()

#全部
l = [4,2,3,1,0]
for i in range(len(file)):
    df = pd.read_csv(file[i]).drop(['Timestamp'],axis=1)
    df["Label"] = [l[i] for j in range(len(df))]
    df_all = pd.concat([df_all,df])

"""
#右左
l = [2,1,0]
for i in range(len(file)):
    df = pd.read_csv(file[i]).drop(['Timestamp'],axis=1)
    df["Label"] = [l[i//6] for j in range(len(df))]
    df_all = pd.concat([df_all,df])
"""
# Out:
# '\n#右左\nl = [2,1,0]\nfor i in range(len(file)):\n    df = pd.read_csv(file[i]).drop([\'Timestamp\'],axis=1)\n    df["Label"] = [l[i//6] for j in range(len(df))]\n    df_all = pd.concat([df_all,df])\n'

# %%
#df_all.reset_index()
df_all
# Out:
#          Cz      Fz      Fp1       F3      C1      C3      T7       C5  \
# 0    74.560   8.735 -184.260 -139.049 -20.467  43.292 -17.302 -113.437
# 1    60.653  -2.544 -200.470 -154.792 -27.619  29.416 -49.048 -121.520
# 2    43.687 -20.985 -224.348 -165.396 -36.300  16.067 -42.851 -132.669
# 3    44.155 -18.915 -209.779 -156.009 -38.826  14.001 -35.123 -131.000
# 4    51.796  -5.576 -179.343 -146.119 -42.373  16.549 -58.654 -124.209
# ..      ...     ...      ...      ...     ...     ...     ...      ...
# 636  44.492  41.083  -69.717  125.284  28.426  37.370  16.156  127.673
# 637  49.058  38.993  -69.647  120.548  30.447  34.259  44.829  125.496
# 638  55.157  36.392  -69.065  113.768  38.101  42.421  77.572  124.346
# 639  49.979  33.794  -86.927  106.994  36.526  40.842  45.219  119.099
# 640  46.343  34.785  -89.914  112.522  29.829  37.727  12.898  127.176
#
#          CP5      CP3  ...     CP2     CP4     CP6      C6      T8      C4  \
# 0   -144.059    3.422  ...  42.167  48.239  -6.887 -27.829 -25.069 -44.250
# 1   -152.624  -12.463  ...  28.292  31.285 -19.688 -47.781 -30.167 -61.625
# 2   -158.619  -21.672  ...  19.555  23.569 -27.353 -57.979 -42.944 -75.395
# 3   -160.510  -22.163  ...  20.560  26.107 -22.202 -51.261 -44.951 -66.611
# 4   -157.276  -22.140  ...  25.150  29.155 -18.594 -44.550 -39.270 -59.372
# ..       ...      ...  ...     ...     ...     ...     ...     ...     ...
# 636  170.989  100.940  ...   4.956  26.664  29.758  79.966  37.997  69.841
# 637  171.843  106.474  ...   8.537  31.248  30.240  76.300  47.181  74.382
# 638  171.158  114.052  ...  10.577  33.778  29.698  73.150  44.060  76.869
# 639  164.327  106.766  ...   6.468  29.134  28.644  72.052  26.597  72.181
# 640  162.114  103.073  ...   2.876  24.494  25.029  71.980  30.157  68.523
#
#          C2       F4      Fp2  Label
# 0    48.242 -111.996  -91.069      4
# 1    29.751 -123.155 -123.253      4
# 2    20.500 -126.618 -145.159      4
# 3    27.139 -113.171 -112.226      4
# 4    27.625  -98.201  -79.326      4
# ..      ...      ...      ...    ...
# 636  16.118   99.043  -31.982      0
# 637  18.151   99.969  -31.437      0
# 638  21.206   98.332  -31.918      0
# 639  16.574   95.160  -45.719      0
# 640  14.509   97.114  -45.673      0
#
# [3214 rows x 30 columns]

# %%
#file = "H_all.csv"
file = "ReALL.csv"

df_all.to_csv(file)
