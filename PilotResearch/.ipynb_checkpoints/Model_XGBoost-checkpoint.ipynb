# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import xgboost as xgb
from scipy import stats
import shap
import seaborn as sns

def calculate_correlations(shap_values, features_df, feature_names, num_classes):
    correlation_df = pd.DataFrame()

    for feature in feature_names:
        correlation_dict = {'feature': feature}

        for i in range(num_classes):
            shap_values_i = shap_values[i][:, features_df.columns.get_loc(feature)]
            feature_values_i = features_df[feature].values

            correlation_coefficient_i = np.corrcoef(shap_values_i, feature_values_i)[0, 1]
            correlation_dict[f'correlation_{i}'] = correlation_coefficient_i

        correlation_df = correlation_df.append(correlation_dict, ignore_index=True)

    return correlation_df

def XGBoost(X, y):
    # データを訓練用とテスト用に分割
    X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    # 訓練データをさらに訓練用と検証用に分割
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=0)

    # モデルのパラメータを設定(CPU)
    params = {
        'objective': 'multi:softmax',
        'eval_metric': 'mlogloss',
        'num_class' : 5,
        'eta': 0.1,
        'max_depth': 12,
        'seed': 0,
        'tree_method': 'gpu_hist',
        'predictor': 'gpu_predictor'
    }
    
    # データをpandas.DataFrame形式で保存
    X_train_df = pd.DataFrame(X_train, columns=column_names)
    y_train_df = pd.DataFrame(y_train, columns=column_names)

    # 訓練データと検証データをXGBoostのDMatrix形式に変換
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)

    # 訓練データと検証データのセットをリストに格納
    evals = [(dtrain, 'train'), (dval, 'eval')]

    # モデルを訓練
    bst = xgb.train(params, dtrain, num_boost_round=10000, evals=evals, early_stopping_rounds=100)

    # テストデータをDMatrix形式に変換
    dtest = xgb.DMatrix(X_test)

    # 訓練データで予測
    y_train_pred = bst.predict(dtrain)

    # テストデータで予測
    y_pred = bst.predict(dtest)

    # 評価
    train_accuracy = accuracy_score(y_train, y_train_pred.round())
    print(f"Training Accuracy: {train_accuracy*100:.2f}%")

    # 評価
    test_accuracy = accuracy_score(y_test, y_pred.round())
    print(f"Test Accuracy: {test_accuracy*100:.2f}%")
        
    return X_train_df, y_train_df, bst

def normalize_per_state(df, start, end):
    scaler = StandardScaler()
    df.iloc[start:end, :] = scaler.fit_transform(df.iloc[start:end, :])
    return df

# %%
# 1秒ごとのデータに分割
n_samples_per_second = 128  # 128Hzのサンプリングレート
#total_seconds = 10  # 全体の秒数

# データの読み込み
df = pd.read_csv('ALL.csv') # 99.48%
#df = pd.read_csv('ALL_RightLeft.csv') # 99.58%
#df = pd.read_csv('ALL_UpperUnder.csv') # 99.69%

"""""
# チャンネルごとに正規化
scaler = StandardScaler()
for column in df.columns[:-1]:  # 'State'列を除くすべての列
    df[column] = scaler.fit_transform(df[column].values.reshape(-1, 1))
"""""
# Out:
# '""\n# チャンネルごとに正規化\nscaler = StandardScaler()\nfor column in df.columns[:-1]:  # \'State\'列を除くすべての列\n    df[column] = scaler.fit_transform(df[column].values.reshape(-1, 1))\n'

# %%
# Hzごと
# 特徴量と目標変数を抽出する
X = df.drop('Label', axis=1)  # 'State'以外の列すべてを特徴量とします
y = df['Label']  # 'State'を目標変数とします

# 列名のリストを定義
column_names = ['Cz', 'Fz', 'Fp1', 'F3', 'C1', 'C3', 'T7', 'C5', 'CP5', 'CP3', 
                'CP1', 'P1', 'P3', 'O1', 'CPz', 'Pz', 'Oz', 'O2', 'P4', 'P2',
                'CP2', 'CP4', 'CP6', 'C6', 'T8', 'C4', 'C2', 'F4', "Fp2"]
#XGBoost
X_train_df, y_train_df, bst = XGBoost(X, y)
# Out:
# [0]	train-mlogloss:1.38171	eval-mlogloss:1.38750
# [1]	train-mlogloss:1.20393	eval-mlogloss:1.21501
# [2]	train-mlogloss:1.05822	eval-mlogloss:1.07267
# [3]	train-mlogloss:0.93629	eval-mlogloss:0.95402
# [4]	train-mlogloss:0.83252	eval-mlogloss:0.85297
# [5]	train-mlogloss:0.74335	eval-mlogloss:0.76588
# [6]	train-mlogloss:0.66511	eval-mlogloss:0.68940
# [7]	train-mlogloss:0.59665	eval-mlogloss:0.62264
# [8]	train-mlogloss:0.53617	eval-mlogloss:0.56346
# [9]	train-mlogloss:0.48265	eval-mlogloss:0.51102
# [10]	train-mlogloss:0.43517	eval-mlogloss:0.46428
# [11]	train-mlogloss:0.39311	eval-mlogloss:0.42292
# [12]	train-mlogloss:0.35526	eval-mlogloss:0.38554
# [13]	train-mlogloss:0.32127	eval-mlogloss:0.35164
# [14]	train-mlogloss:0.29102	eval-mlogloss:0.32153
# [15]	train-mlogloss:0.26365	eval-mlogloss:0.29431
# [16]	train-mlogloss:0.23923	eval-mlogloss:0.27006
# [17]	train-mlogloss:0.21708	eval-mlogloss:0.24776
# [18]	train-mlogloss:0.19725	eval-mlogloss:0.22777
# [19]	train-mlogloss:0.17931	eval-mlogloss:0.20971
# [20]	train-mlogloss:0.16307	eval-mlogloss:0.19324
# [21]	train-mlogloss:0.14850	eval-mlogloss:0.17829
# [22]	train-mlogloss:0.13517	eval-mlogloss:0.16442
# [23]	train-mlogloss:0.12314	eval-mlogloss:0.15201
# [24]	train-mlogloss:0.11224	eval-mlogloss:0.14074
# [25]	train-mlogloss:0.10240	eval-mlogloss:0.13036
# [26]	train-mlogloss:0.09350	eval-mlogloss:0.12079
# [27]	train-mlogloss:0.08544	eval-mlogloss:0.11236
# [28]	train-mlogloss:0.07807	eval-mlogloss:0.10451
# [29]	train-mlogloss:0.07140	eval-mlogloss:0.09730
# [30]	train-mlogloss:0.06537	eval-mlogloss:0.09082
# [31]	train-mlogloss:0.05994	eval-mlogloss:0.08486
# [32]	train-mlogloss:0.05500	eval-mlogloss:0.07931
# [33]	train-mlogloss:0.05047	eval-mlogloss:0.07425
# [34]	train-mlogloss:0.04638	eval-mlogloss:0.06965
# [35]	train-mlogloss:0.04267	eval-mlogloss:0.06547
# [36]	train-mlogloss:0.03930	eval-mlogloss:0.06167
# [37]	train-mlogloss:0.03625	eval-mlogloss:0.05828
# [38]	train-mlogloss:0.03347	eval-mlogloss:0.05508
# [39]	train-mlogloss:0.03091	eval-mlogloss:0.05229
# [40]	train-mlogloss:0.02856	eval-mlogloss:0.04954
# [41]	train-mlogloss:0.02645	eval-mlogloss:0.04700
# [42]	train-mlogloss:0.02454	eval-mlogloss:0.04463
# [43]	train-mlogloss:0.02277	eval-mlogloss:0.04243
# [44]	train-mlogloss:0.02117	eval-mlogloss:0.04057
# [45]	train-mlogloss:0.01970	eval-mlogloss:0.03868
# [46]	train-mlogloss:0.01834	eval-mlogloss:0.03704
# [47]	train-mlogloss:0.01712	eval-mlogloss:0.03552
# [48]	train-mlogloss:0.01597	eval-mlogloss:0.03395
# [49]	train-mlogloss:0.01491	eval-mlogloss:0.03261
# [50]	train-mlogloss:0.01395	eval-mlogloss:0.03132
# [51]	train-mlogloss:0.01305	eval-mlogloss:0.03014
# [52]	train-mlogloss:0.01224	eval-mlogloss:0.02902
# [53]	train-mlogloss:0.01150	eval-mlogloss:0.02804
# [54]	train-mlogloss:0.01080	eval-mlogloss:0.02692
# [55]	train-mlogloss:0.01019	eval-mlogloss:0.02608
# [56]	train-mlogloss:0.00960	eval-mlogloss:0.02514
# [57]	train-mlogloss:0.00906	eval-mlogloss:0.02431
# [58]	train-mlogloss:0.00855	eval-mlogloss:0.02358
# [59]	train-mlogloss:0.00811	eval-mlogloss:0.02295
# [60]	train-mlogloss:0.00768	eval-mlogloss:0.02224
# [61]	train-mlogloss:0.00729	eval-mlogloss:0.02168
# [62]	train-mlogloss:0.00694	eval-mlogloss:0.02122
# [63]	train-mlogloss:0.00661	eval-mlogloss:0.02066
# [64]	train-mlogloss:0.00630	eval-mlogloss:0.02014
# [65]	train-mlogloss:0.00603	eval-mlogloss:0.01973
# [66]	train-mlogloss:0.00575	eval-mlogloss:0.01925
# [67]	train-mlogloss:0.00551	eval-mlogloss:0.01880
# [68]	train-mlogloss:0.00528	eval-mlogloss:0.01856
# [69]	train-mlogloss:0.00506	eval-mlogloss:0.01823
# [70]	train-mlogloss:0.00487	eval-mlogloss:0.01794
# [71]	train-mlogloss:0.00468	eval-mlogloss:0.01759
# [72]	train-mlogloss:0.00450	eval-mlogloss:0.01729
# [73]	train-mlogloss:0.00435	eval-mlogloss:0.01704
# [74]	train-mlogloss:0.00418	eval-mlogloss:0.01676
# [75]	train-mlogloss:0.00404	eval-mlogloss:0.01648
# [76]	train-mlogloss:0.00390	eval-mlogloss:0.01627
# [77]	train-mlogloss:0.00376	eval-mlogloss:0.01603
# [78]	train-mlogloss:0.00364	eval-mlogloss:0.01580
# [79]	train-mlogloss:0.00352	eval-mlogloss:0.01551
# [80]	train-mlogloss:0.00340	eval-mlogloss:0.01521
# [81]	train-mlogloss:0.00330	eval-mlogloss:0.01498
# [82]	train-mlogloss:0.00321	eval-mlogloss:0.01473
# [83]	train-mlogloss:0.00312	eval-mlogloss:0.01458
# [84]	train-mlogloss:0.00303	eval-mlogloss:0.01435
# [85]	train-mlogloss:0.00295	eval-mlogloss:0.01416
# [86]	train-mlogloss:0.00286	eval-mlogloss:0.01399
# [87]	train-mlogloss:0.00279	eval-mlogloss:0.01382
# [88]	train-mlogloss:0.00272	eval-mlogloss:0.01370
# [89]	train-mlogloss:0.00265	eval-mlogloss:0.01350
# [90]	train-mlogloss:0.00259	eval-mlogloss:0.01332
# [91]	train-mlogloss:0.00253	eval-mlogloss:0.01319
# [92]	train-mlogloss:0.00247	eval-mlogloss:0.01304
# [93]	train-mlogloss:0.00241	eval-mlogloss:0.01283
# [94]	train-mlogloss:0.00236	eval-mlogloss:0.01270
# [95]	train-mlogloss:0.00231	eval-mlogloss:0.01258
# [96]	train-mlogloss:0.00227	eval-mlogloss:0.01245
# [97]	train-mlogloss:0.00222	eval-mlogloss:0.01230
# [98]	train-mlogloss:0.00218	eval-mlogloss:0.01221
# [99]	train-mlogloss:0.00213	eval-mlogloss:0.01211
# [100]	train-mlogloss:0.00209	eval-mlogloss:0.01201
# [101]	train-mlogloss:0.00206	eval-mlogloss:0.01194
# [102]	train-mlogloss:0.00202	eval-mlogloss:0.01184
# [103]	train-mlogloss:0.00198	eval-mlogloss:0.01176
# [104]	train-mlogloss:0.00195	eval-mlogloss:0.01169
# [105]	train-mlogloss:0.00192	eval-mlogloss:0.01159
# [106]	train-mlogloss:0.00188	eval-mlogloss:0.01149
# [107]	train-mlogloss:0.00185	eval-mlogloss:0.01146
# [108]	train-mlogloss:0.00182	eval-mlogloss:0.01134
# [109]	train-mlogloss:0.00180	eval-mlogloss:0.01126
# [110]	train-mlogloss:0.00177	eval-mlogloss:0.01121
# [111]	train-mlogloss:0.00174	eval-mlogloss:0.01117
# [112]	train-mlogloss:0.00172	eval-mlogloss:0.01114
# [113]	train-mlogloss:0.00170	eval-mlogloss:0.01107
# [114]	train-mlogloss:0.00167	eval-mlogloss:0.01104
# [115]	train-mlogloss:0.00165	eval-mlogloss:0.01097
# [116]	train-mlogloss:0.00163	eval-mlogloss:0.01092
# [117]	train-mlogloss:0.00161	eval-mlogloss:0.01085
# [118]	train-mlogloss:0.00159	eval-mlogloss:0.01078
# [119]	train-mlogloss:0.00157	eval-mlogloss:0.01070
# [120]	train-mlogloss:0.00155	eval-mlogloss:0.01067
# [121]	train-mlogloss:0.00153	eval-mlogloss:0.01061
# [122]	train-mlogloss:0.00151	eval-mlogloss:0.01058
# [123]	train-mlogloss:0.00149	eval-mlogloss:0.01052
# [124]	train-mlogloss:0.00147	eval-mlogloss:0.01050
# [125]	train-mlogloss:0.00146	eval-mlogloss:0.01049
# [126]	train-mlogloss:0.00144	eval-mlogloss:0.01045
# [127]	train-mlogloss:0.00143	eval-mlogloss:0.01041
# [128]	train-mlogloss:0.00141	eval-mlogloss:0.01037
# [129]	train-mlogloss:0.00140	eval-mlogloss:0.01030
# [130]	train-mlogloss:0.00138	eval-mlogloss:0.01031
# [131]	train-mlogloss:0.00137	eval-mlogloss:0.01028
# [132]	train-mlogloss:0.00136	eval-mlogloss:0.01027
# [133]	train-mlogloss:0.00134	eval-mlogloss:0.01023
# [134]	train-mlogloss:0.00133	eval-mlogloss:0.01018
# [135]	train-mlogloss:0.00132	eval-mlogloss:0.01015
# [136]	train-mlogloss:0.00131	eval-mlogloss:0.01011
# [137]	train-mlogloss:0.00130	eval-mlogloss:0.01008
# [138]	train-mlogloss:0.00128	eval-mlogloss:0.01005
# [139]	train-mlogloss:0.00127	eval-mlogloss:0.01002
# [140]	train-mlogloss:0.00126	eval-mlogloss:0.00999
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# invalid value encountered in divide
# invalid value encountered in divide
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                      0         1         2         3         4         5   \
# feature              Cz        Fz       Fp1        F3        C1        C3
# correlation_0  0.810988 -0.766331 -0.625519 -0.612685  0.862686 -0.758824
# correlation_1 -0.769314 -0.463344 -0.804074 -0.532088 -0.455273   0.85354
# correlation_2 -0.781393  0.693305 -0.731118 -0.685555  0.794201 -0.720798
# correlation_3  0.800697 -0.488101   0.85363  0.631584 -0.664009  0.326075
# correlation_4  0.443738  0.814355  0.730295  0.799195 -0.879276   0.75615
#
#                      6         7         8         9   ...        19  \
# feature              T7        C5       CP5       CP3  ...        P2
# correlation_0 -0.297234  0.788873 -0.632299 -0.809433  ... -0.697578
# correlation_1  0.924133  0.722813  0.560965       NaN  ...   0.78542
# correlation_2 -0.708802 -0.695566  0.822583  0.569177  ... -0.564023
# correlation_3  0.799863 -0.731817  0.580333 -0.697619  ... -0.776853
# correlation_4 -0.892087  -0.87551 -0.802491 -0.706897  ...  0.818273
#
#                      20        21        22        23        24        25  \
# feature             CP2       CP4       CP6        C6        T8        C4
# correlation_0  0.106143 -0.241362  0.795139 -0.700924 -0.872544  -0.59979
# correlation_1 -0.374326   0.81424 -0.831902 -0.669027  0.892211  0.141122
# correlation_2 -0.317611 -0.639801 -0.804692 -0.448782  -0.78174 -0.581498
# correlation_3  0.667152  0.659022  0.823234  0.765331 -0.877457  0.468709
# correlation_4 -0.058002 -0.851632  0.761499  0.766336  0.798987 -0.480074
#
#                      26        27        28
# feature              C2        F4       Fp2
# correlation_0  0.532927 -0.640828  0.868505
# correlation_1  0.121532 -0.718754 -0.008991
# correlation_2  0.256973  0.641458  0.792439
# correlation_3 -0.287248 -0.046952 -0.489249
# correlation_4    -0.849 -0.704647  -0.78582
#
# [6 rows x 29 columns]

# %% [raw]
# """
# #１秒ごとに分割
# # ラベルの作成（5秒閉じ、5秒開け）
# labels_close = [0] * 5 *64
# labels_open = [1] * 5 * 64
# labels = labels_close + labels_open
#
# #labels = df.iloc[:, -1]
#
# #14chデータ
# n_samples_per_second = 4
# total_seconds = 10  # 全体の秒数
# #total_seconds = 3242  # 全体の秒数
#
# # データとラベルを1秒ごとに分割
# #X = np.array([df.iloc[i*n_samples_per_second:(i+1)*n_samples_per_second, :-1].values for i in range(total_seconds)])
#
# X = np.array([df.iloc[i*n_samples_per_second:(i+1)*n_samples_per_second, :-1].values for i in range(total_seconds*64)])
# #labels = np.array([stats.mode(y[i*n_samples_per_second:(i+1)*n_samples_per_second])[0][0] for i in range(total_seconds*64)])
#
#
# # 1秒ごとのデータの平均を取得
# X = X.mean(axis=1)
#
# #XGBoost
# XGBoost(X, labels)
#
# #plot
# #plot_importance(raw, model1)
#
# """
