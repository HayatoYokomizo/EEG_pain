# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
import mne
from mne.preprocessing import ICA
from datetime import datetime


def plot_data(data, ch_names):
    plt.figure(figsize=(15, 8))
    timestamps = [float(row['timestamp']) for row in data]

    for ch_name in ch_names:
        ch_data = [float(row[ch_name]) for row in data]
        plt.plot(timestamps, ch_data, label=ch_name)

    plt.xlabel('Time (s)')
    plt.ylabel('Sensor Value')
    plt.title('Brainwave Data')
    plt.legend()
    plt.show()
    
#csvに保存
def save_clean_data_to_csv(raw_clean, ch_names, filename):
    data = raw_clean.get_data().T
    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['timestamp'] + ch_names)
        for i, row in enumerate(data):
            timestamp = raw_clean.times[i]
            writer.writerow([timestamp] + list(row))
            
def load_data_from_csv(filename):
    data = []
    with open(filename, 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

def create_mne_raw_object(data, ch_names, sfreq):
    n_channels = len(ch_names)
    n_samples = len(data)

    data_array = np.empty((n_channels, n_samples))
    for i, row in enumerate(data):
        for j, ch_name in enumerate(ch_names):
            data_array[j, i] = float(row[ch_name])

    info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types='eeg')
    raw = mne.io.RawArray(data_array, info)
    return raw

# %%
#ICA(OpenEyes)
filename = 'OpenEyes.csv'
data = load_data_from_csv(filename)

# 選択したチャンネルをプロット
ch_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']
sfreq =  256 # サンプリング周波数

raw = create_mne_raw_object(data, ch_names, sfreq)

# 事前にハイパスフィルタを適用してデータのトレンドを除去
raw.filter(l_freq=1, h_freq=None)

# ICAを実行
ica = ICA(n_components=14, random_state=0, max_iter=100000)
ica.fit(raw)

# ICA成分をプロット
ica.plot_sources(raw)



# ICA 成分と他のチャンネルとの相関を計算
ica_sources = ica.get_sources(raw).get_data()
raw_data = raw.get_data()
stacked_data = np.vstack((ica_sources, raw_data))
corr_matrix = np.corrcoef(stacked_data)

# 閾値以上の相関がある成分を特定
threshold = 0.8 #なんとなく0.8
n_ica_components = ica_sources.shape[0]
bad_indices = np.where(np.abs(corr_matrix[:n_ica_components, n_ica_components:]) > threshold)

# 眼球運動に関連する成分のインデックスを追加
ica.exclude = np.unique(bad_indices[0])

# ICA を適用してノイズを除去
raw_clean = raw.copy()
ica.apply(raw_clean)
            
filename = 'OpenEyes_NoiseRemoval_A.csv'
save_clean_data_to_csv(raw_clean, ch_names, filename)



# データの読み込み
data1 = load_data_from_csv('OpenEyes.csv')
data2 = load_data_from_csv('OpenEyes_NoiseRemoval_A.csv')

# チャンネルを選択
channels = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']

# サブプロットの作成 (2行1列)
fig, axs = plt.subplots(2, 1, figsize=(15, 16))

# データ1のプロット
for channel in channels:
    values = [float(row[channel]) for row in data1]
    axs[0].plot([i/sfreq for i in range(len(values))], values, label=channel)
axs[0].set_title('OpenEyes')
axs[0].set_xlabel('Time (seconds)')
axs[0].set_ylabel('EEG')
axs[0].legend()

# データ2のプロット
for channel in channels:
    values = [float(row[channel]) for row in data2]
    axs[1].plot([i/sfreq for i in range(len(values))], values, label=channel)
axs[1].set_title('OpenEyes_NoiseRemoval_A')
axs[1].set_xlabel('Time (seconds)')
axs[1].set_ylabel('EEG')
axs[1].legend()

plt.tight_layout()
plt.show()
# Out:
# Creating RawArray with float64 data, n_channels=14, n_times=1282
#     Range : 0 ... 1281 =      0.000 ...     5.004 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 845 samples (3.301 sec)
#
# Fitting ICA to data using 14 channels (please be patient, this may take a while)
# Selecting by number: 14 components
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.0s finished
# Fitting ICA took 38.1s.
# Creating RawArray with float64 data, n_channels=14, n_times=1282
#     Range : 0 ... 1281 =      0.000 ...     5.004 secs
# Ready.
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Applying ICA to Raw instance
#     Transforming to ICA space (14 components)
#     Zeroing out 0 ICA components
#     Projecting back using 14 PCA components

# %%
#手動によるEOG(眼球運動)除去のためのもの
"""
filename = "OpenEyes.csv"
data = load_data_from_csv(filename)

# 選択したチャンネルをプロット
ch_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']
sfreq =  256 # サンプリング周波数

raw = create_mne_raw_object(data, ch_names, sfreq)

# 事前にハイパスフィルタを適用してデータのトレンドを除去
raw.filter(l_freq=1, h_freq=None)

# ICAを実行
ica = ICA(n_components=14, random_state=0, max_iter=10000)
ica.fit(raw)

# 眼球運動に関連する成分のインデックスを追加
EOG_index = 0 #EOGだと思われるインデクス番号（データによって異なる）
ica.exclude = [EOG_index] 

# ICA を適用してノイズを除去
raw_clean = raw.copy()
ica.apply(raw_clean)
    
filename = 'OpenEyes_NoiseRemoval_M.csv'
save_clean_data_to_csv(raw_clean, ch_names, filename)
"""


#アーティファクト検出アルゴリズムを使用したもの(全体から相関をもとめる)
#ICA 成分と他のチャンネルとの相関を計算し、相関が閾値以上の成分を自動的に除去するプログラム

"""
filename = "OpenEyes.csv"
data = load_data_from_csv(filename)

# 選択したチャンネルをプロット
ch_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']
sfreq =  256 # サンプリング周波数

raw = create_mne_raw_object(data, ch_names, sfreq)

# 事前にハイパスフィルタを適用してデータのトレンドを除去
raw.filter(l_freq=1, h_freq=None)

# ICAを実行
ica = ICA(n_components=14, random_state=0, max_iter=10000)
ica.fit(raw)

# ICA 成分と他のチャンネルとの相関を計算
ica_sources = ica.get_sources(raw).get_data()
raw_data = raw.get_data()
stacked_data = np.vstack((ica_sources, raw_data))
corr_matrix = np.corrcoef(stacked_data)

# 閾値以上の相関がある成分を特定
threshold = 0.8 #なんとなく0.8
n_ica_components = ica_sources.shape[0]
bad_indices = np.where(np.abs(corr_matrix[:n_ica_components, n_ica_components:]) > threshold)

# 眼球運動に関連する成分のインデックスを追加
ica.exclude = np.unique(bad_indices[0])

# ICA を適用してノイズを除去
raw_clean = raw.copy()
ica.apply(raw_clean)
            
filename = 'OpenEyes_NoiseRemoval_A.csv'
save_clean_data_to_csv(raw_clean, ch_names, filename)
"""

"""
#plot
# データの読み込み
data1 = load_data_from_csv('OpenEyes.csv')
data2 = load_data_from_csv('OpenEyes_NoiseRemoval_A.csv')

# チャンネルを選択
channels = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']

# サンプリングレート
sfreq = 256

# サブプロットの作成 (2行1列)
fig, axs = plt.subplots(2, 1, figsize=(15, 16))

# データ1のプロット
for channel in channels:
    values = [float(row[channel]) for row in data1]
    axs[0].plot([i/sfreq for i in range(len(values))], values, label=channel)
axs[0].set_title('OpenEyes')
axs[0].set_xlabel('Time (seconds)')
axs[0].set_ylabel('EEG')
axs[0].legend()

# データ2のプロット
for channel in channels:
    values = [float(row[channel]) for row in data2]
    axs[1].plot([i/sfreq for i in range(len(values))], values, label=channel)
axs[1].set_title('OpenEyes_NoiseRemoval_A')
axs[1].set_xlabel('Time (seconds)')
axs[1].set_ylabel('EEG')
axs[1].legend()

plt.tight_layout()
plt.show()
"""
# Out:
# "\n#plot\n# データの読み込み\ndata1 = load_data_from_csv('OpenEyes.csv')\ndata2 = load_data_from_csv('OpenEyes_NoiseRemoval_A.csv')\n\n# チャンネルを選択\nchannels = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']\n\n# サンプリングレート\nsfreq = 256\n\n# サブプロットの作成 (2行1列)\nfig, axs = plt.subplots(2, 1, figsize=(15, 16))\n\n# データ1のプロット\nfor channel in channels:\n    values = [float(row[channel]) for row in data1]\n    axs[0].plot([i/sfreq for i in range(len(values))], values, label=channel)\naxs[0].set_title('OpenEyes')\naxs[0].set_xlabel('Time (seconds)')\naxs[0].set_ylabel('EEG')\naxs[0].legend()\n\n# データ2のプロット\nfor channel in channels:\n    values = [float(row[channel]) for row in data2]\n    axs[1].plot([i/sfreq for i in range(len(values))], values, label=channel)\naxs[1].set_title('OpenEyes_NoiseRemoval_A')\naxs[1].set_xlabel('Time (seconds)')\naxs[1].set_ylabel('EEG')\naxs[1].legend()\n\nplt.tight_layout()\nplt.show()\n"

# %%
####ICA(CloseEyes)
filename = 'CloseEyes.csv'
data = load_data_from_csv(filename)

# 選択したチャンネルをプロット
ch_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']
sfreq =  256 # サンプリング周波数

raw = create_mne_raw_object(data, ch_names, sfreq)

# 事前にハイパスフィルタを適用してデータのトレンドを除去
raw.filter(l_freq=1, h_freq=None)

# ICAを実行
ica = ICA(n_components=14, random_state=0, max_iter=100000)
ica.fit(raw)

# ICA成分をプロット
ica.plot_sources(raw)

# ICA 成分と他のチャンネルとの相関を計算
ica_sources = ica.get_sources(raw).get_data()
raw_data = raw.get_data()
stacked_data = np.vstack((ica_sources, raw_data))
corr_matrix = np.corrcoef(stacked_data)

# 閾値以上の相関がある成分を特定
threshold = 0.8 #なんとなく0.8
n_ica_components = ica_sources.shape[0]
bad_indices = np.where(np.abs(corr_matrix[:n_ica_components, n_ica_components:]) > threshold)

# 眼球運動に関連する成分のインデックスを追加
ica.exclude = np.unique(bad_indices[0])

# ICA を適用してノイズを除去
raw_clean = raw.copy()
ica.apply(raw_clean)
            
filename = 'CloseEyes_NoiseRemoval_A.csv'
save_clean_data_to_csv(raw_clean, ch_names, filename)



#####plot
# データの読み込み
data1 = load_data_from_csv('CloseEyes.csv')
data2 = load_data_from_csv('CloseEyes_NoiseRemoval_A.csv')

# チャンネルを選択
channels = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']

# サブプロットの作成 (2行1列)
fig, axs = plt.subplots(2, 1, figsize=(15, 16))

# データ1のプロット
for channel in channels:
    values = [float(row[channel]) for row in data1]
    axs[0].plot([i/sfreq for i in range(len(values))], values, label=channel)
axs[0].set_title('CloseEyes')
axs[0].set_xlabel('Time (seconds)')
axs[0].set_ylabel('EEG')
axs[0].legend()

# データ2のプロット
for channel in channels:
    values = [float(row[channel]) for row in data2]
    axs[1].plot([i/sfreq for i in range(len(values))], values, label=channel)
axs[1].set_title('CloseEyes_NoiseRemoval_A')
axs[1].set_xlabel('Time (seconds)')
axs[1].set_ylabel('EEG')
axs[1].legend()

plt.tight_layout()
plt.show()
# Out:
# Creating RawArray with float64 data, n_channels=14, n_times=1282
#     Range : 0 ... 1281 =      0.000 ...     5.004 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 845 samples (3.301 sec)
#
# Fitting ICA to data using 14 channels (please be patient, this may take a while)
# Selecting by number: 14 components
# Fitting ICA took 0.0s.
# Creating RawArray with float64 data, n_channels=14, n_times=1282
#     Range : 0 ... 1281 =      0.000 ...     5.004 secs
# Ready.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.0s finished
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Applying ICA to Raw instance
#     Transforming to ICA space (14 components)
#     Zeroing out 0 ICA components
#     Projecting back using 14 PCA components

# %%
#手動によるEOG(眼球運動)除去のためのもの
"""
filename = "CloseEyes.csv"
data = load_data_from_csv(filename)

# 選択したチャンネルをプロット
ch_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']
sfreq =  256 # サンプリング周波数

raw = create_mne_raw_object(data, ch_names, sfreq)

# 事前にハイパスフィルタを適用してデータのトレンドを除去
raw.filter(l_freq=1, h_freq=None)

# ICAを実行
ica = ICA(n_components=14, random_state=0, max_iter=10000)
ica.fit(raw)

# 眼球運動に関連する成分のインデックスを追加
EOG_index = 0 #EOGだと思われるインデクス番号（データによって異なる）
ica.exclude = [EOG_index] 

# ICA を適用してノイズを除去
raw_clean = raw.copy()
ica.apply(raw_clean)
    
filename = 'CloseEyes_NoiseRemoval_M.csv'
save_clean_data_to_csv(raw_clean, ch_names, filename)

"""


#アーティファクト検出アルゴリズムを使用したもの(全体から相関をもとめる)
#ICA 成分と他のチャンネルとの相関を計算し、相関が閾値以上の成分を自動的に除去するプログラム

"""
filename = "CloseEyes.csv"
data = load_data_from_csv(filename)

# 選択したチャンネルをプロット
ch_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']
sfreq =  256 # サンプリング周波数

raw = create_mne_raw_object(data, ch_names, sfreq)

# 事前にハイパスフィルタを適用してデータのトレンドを除去
raw.filter(l_freq=1, h_freq=None)

# ICAを実行
ica = ICA(n_components=14, random_state=0, max_iter=10000)
ica.fit(raw)

# ICA 成分と他のチャンネルとの相関を計算
ica_sources = ica.get_sources(raw).get_data()
raw_data = raw.get_data()
stacked_data = np.vstack((ica_sources, raw_data))
corr_matrix = np.corrcoef(stacked_data)

# 閾値以上の相関がある成分を特定
threshold = 0.8 #なんとなく0.8
n_ica_components = ica_sources.shape[0]
bad_indices = np.where(np.abs(corr_matrix[:n_ica_components, n_ica_components:]) > threshold)

# 眼球運動に関連する成分のインデックスを追加
ica.exclude = np.unique(bad_indices[0])

# ICA を適用してノイズを除去
raw_clean = raw.copy()
ica.apply(raw_clean)
            
filename = 'CloseEyes_NoiseRemoval_A.csv'
save_clean_data_to_csv(raw_clean, ch_names, filename)
"""

"""
###plot
# データの読み込み
data1 = load_data_from_csv('CloseEyes.csv')
data2 = load_data_from_csv('CloseEyes_NoiseRemoval_A.csv')

# チャンネルを選択
channels = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']

# サンプリングレート
sfreq = 256

# サブプロットの作成 (2行1列)
fig, axs = plt.subplots(2, 1, figsize=(15, 16))

# データ1のプロット
for channel in channels:
    values = [float(row[channel]) for row in data1]
    axs[0].plot([i/sfreq for i in range(len(values))], values, label=channel)
axs[0].set_title('CloseEyes')
axs[0].set_xlabel('Time (seconds)')
axs[0].set_ylabel('EEG')
axs[0].legend()

# データ2のプロット
for channel in channels:
    values = [float(row[channel]) for row in data2]
    axs[1].plot([i/sfreq for i in range(len(values))], values, label=channel)
axs[1].set_title('CloseEyes_NoiseRemoval_A')
axs[1].set_xlabel('Time (seconds)')
axs[1].set_ylabel('EEG')
axs[1].legend()

plt.tight_layout()
plt.show()
"""
# Out:
# "\n###plot\n# データの読み込み\ndata1 = load_data_from_csv('CloseEyes.csv')\ndata2 = load_data_from_csv('CloseEyes_NoiseRemoval_A.csv')\n\n# チャンネルを選択\nchannels = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']\n\n# サンプリングレート\nsfreq = 256\n\n# サブプロットの作成 (2行1列)\nfig, axs = plt.subplots(2, 1, figsize=(15, 16))\n\n# データ1のプロット\nfor channel in channels:\n    values = [float(row[channel]) for row in data1]\n    axs[0].plot([i/sfreq for i in range(len(values))], values, label=channel)\naxs[0].set_title('CloseEyes')\naxs[0].set_xlabel('Time (seconds)')\naxs[0].set_ylabel('EEG')\naxs[0].legend()\n\n# データ2のプロット\nfor channel in channels:\n    values = [float(row[channel]) for row in data2]\n    axs[1].plot([i/sfreq for i in range(len(values))], values, label=channel)\naxs[1].set_title('CloseEyes_NoiseRemoval_A')\naxs[1].set_xlabel('Time (seconds)')\naxs[1].set_ylabel('EEG')\naxs[1].legend()\n\nplt.tight_layout()\nplt.show()\n"
