# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM


# モデル定義
def create_model_LSTM():
    model = Sequential()
    model.add(LSTM(32, input_shape=(n_samples_per_second, 14)))  # 入力の形状は（1秒ごとのサンプル数, 特徴量の数）
    model.add(Dense(16, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # バイナリ分類なので出力は1、活性化関数はsigmoid

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # 損失関数はbinary_crossentropy
    return model

# モデル定義
def create_model_NT():
    model = Sequential()
    model.add(Dense(32, activation='relu', input_shape=(14,)))  # 入力の形状は（特徴量の数）
    model.add(Dense(16, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # バイナリ分類なので出力は1、活性化関数はsigmoid
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # 損失関数はbinary_crossentropy
    return model

# %%
#LSTMによる学習モデル（目が明いているか閉じているかを時系列的にみたモデル）

# データの読み込み
df = pd.read_csv('Raw.csv')

# 1秒ごとのデータに分割
n_samples_per_second = 256  # 256Hzのサンプリングレート
total_seconds = 10  # 全体の秒数

# ラベルの作成（5秒閉じ、5秒開け）
labels_close = [0] * 5
labels_open = [1] * 5
labels = labels_close + labels_open

# データとラベルを1秒ごとに分割
X = [df.iloc[i*n_samples_per_second:(i+1)*n_samples_per_second, :-1].values for i in range(total_seconds)]
y = labels

# 全データを一度に扱うためのリスト
X_all = []
y_all = []

# 各1秒ごとのデータセットに対してモデルを訓練
for i in range(total_seconds):
    # データの正規化
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X[i])
    X_all.append(X_scaled)

# データをnumpy配列に変換
X_all = np.array(X_all)

# 学習用とテスト用に分割
X_train, X_test, y_train, y_test = train_test_split(X_all, np.array(labels), test_size=0.2, random_state=0)

# モデル作成
model = create_model_LSTM()

# 学習
model.fit(X_train, y_train, epochs=50, batch_size=1, verbose=1)

# 訓練データに対する評価
train_scores = model.evaluate(X_train, y_train, verbose=1)
print(f"Training Accuracy: {train_scores[1]*100}")

# テストデータに対する評価
test_scores = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Accuracy: {test_scores[1]*100}")
# Out:
# Epoch 1/50
# 8/8 [==============================] - 3s 43ms/step - loss: 0.7177 - accuracy: 0.5000
# Epoch 2/50
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6439 - accuracy: 0.5000
# Epoch 3/50
# 8/8 [==============================] - 0s 44ms/step - loss: 0.6010 - accuracy: 0.7500
# Epoch 4/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5693 - accuracy: 0.7500
# Epoch 5/50
# 8/8 [==============================] - 0s 43ms/step - loss: 0.5344 - accuracy: 1.0000
# Epoch 6/50
# 8/8 [==============================] - 0s 40ms/step - loss: 0.4955 - accuracy: 1.0000
# Epoch 7/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4653 - accuracy: 1.0000
# Epoch 8/50
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4324 - accuracy: 1.0000
# Epoch 9/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3991 - accuracy: 1.0000
# Epoch 10/50
# 8/8 [==============================] - 0s 44ms/step - loss: 0.3699 - accuracy: 1.0000
# Epoch 11/50
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3408 - accuracy: 1.0000
# Epoch 12/50
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3143 - accuracy: 1.0000
# Epoch 13/50
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2907 - accuracy: 1.0000
# Epoch 14/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2694 - accuracy: 1.0000
# Epoch 15/50
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2440 - accuracy: 1.0000
# Epoch 16/50
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2227 - accuracy: 1.0000
# Epoch 17/50
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1943 - accuracy: 1.0000
# Epoch 18/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1733 - accuracy: 1.0000
# Epoch 19/50
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1488 - accuracy: 1.0000
# Epoch 20/50
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1295 - accuracy: 1.0000
# Epoch 21/50
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1111 - accuracy: 1.0000
# Epoch 22/50
# 8/8 [==============================] - 0s 41ms/step - loss: 0.0944 - accuracy: 1.0000
# Epoch 23/50
# 8/8 [==============================] - 0s 43ms/step - loss: 0.0760 - accuracy: 1.0000
# Epoch 24/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0651 - accuracy: 1.0000
# Epoch 25/50
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0550 - accuracy: 1.0000
# Epoch 26/50
# 8/8 [==============================] - 0s 43ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 27/50
# 8/8 [==============================] - 0s 45ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 28/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 29/50
# 8/8 [==============================] - 0s 43ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 30/50
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 31/50
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 32/50
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 33/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 34/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 35/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 36/50
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 37/50
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 38/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 39/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 40/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 41/50
# 8/8 [==============================] - 0s 42ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 42/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 43/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 44/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 45/50
# 8/8 [==============================] - 0s 41ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 46/50
# 8/8 [==============================] - 0s 43ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 47/50
# 8/8 [==============================] - 0s 46ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 48/50
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 49/50
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 50/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0082 - accuracy: 1.0000
# 1/1 [==============================] - 1s 572ms/step - loss: 0.0077 - accuracy: 1.0000
# Training Accuracy: 100.0
# 1/1 [==============================] - 0s 41ms/step - loss: 2.0139 - accuracy: 0.5000
# Test Accuracy: 50.0

# %%
#時系列的に見なかった場合
# データの読み込み
df = pd.read_csv('Raw.csv')

# 特徴量とラベルを取得
X = df.drop('State', axis=1).values
y = df['State'].values

# データの正規化
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 学習用とテスト用に分割
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.8, random_state=0)

# モデル作成
model = create_model_NT()

# 学習
model.fit(X_train, y_train, epochs=50, batch_size=1, verbose=1)

# 訓練データに対する評価
train_scores = model.evaluate(X_train, y_train, verbose=1)
print(f"Training Accuracy: {train_scores[1]*100}")

# テストデータに対する評価
test_scores = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Accuracy: {test_scores[1]*100}")
# Out:
# Epoch 1/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.4247 - accuracy: 0.8398
# Epoch 2/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.1592 - accuracy: 0.9590
# Epoch 3/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.0724 - accuracy: 0.9785
# Epoch 4/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.0406 - accuracy: 0.9902
# Epoch 5/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.0360 - accuracy: 0.9883
# Epoch 6/50
# 512/512 [==============================] - 1s 2ms/step - loss: 0.0194 - accuracy: 0.9961
# Epoch 7/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.0175 - accuracy: 0.9941
# Epoch 8/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 9/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 10/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 11/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 12/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 13/50
# 512/512 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 14/50
# 512/512 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 15/50
# 512/512 [==============================] - 1s 2ms/step - loss: 7.0177e-04 - accuracy: 1.0000
# Epoch 16/50
# 512/512 [==============================] - 1s 2ms/step - loss: 5.4258e-04 - accuracy: 1.0000
# Epoch 17/50
# 512/512 [==============================] - 1s 1ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 18/50
# 512/512 [==============================] - 1s 2ms/step - loss: 5.4768e-04 - accuracy: 1.0000
# Epoch 19/50
# 512/512 [==============================] - 1s 1ms/step - loss: 1.9995e-04 - accuracy: 1.0000
# Epoch 20/50
# 512/512 [==============================] - 1s 1ms/step - loss: 1.4698e-04 - accuracy: 1.0000
# Epoch 21/50
# 512/512 [==============================] - 1s 1ms/step - loss: 1.1599e-04 - accuracy: 1.0000
# Epoch 22/50
# 512/512 [==============================] - 1s 1ms/step - loss: 9.1489e-05 - accuracy: 1.0000
