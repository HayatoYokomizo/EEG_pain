# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import xgboost as xgb
from scipy import stats
import shap
import seaborn as sns

def calculate_correlations(shap_values, features_df, feature_names, num_classes):
    correlation_df = pd.DataFrame()

    for feature in feature_names:
        correlation_dict = {'feature': feature}

        for i in range(num_classes):
            shap_values_i = shap_values[i][:, features_df.columns.get_loc(feature)]
            feature_values_i = features_df[feature].values

            correlation_coefficient_i = np.corrcoef(shap_values_i, feature_values_i)[0, 1]
            correlation_dict[f'correlation_{i}'] = correlation_coefficient_i

        correlation_df = correlation_df.append(correlation_dict, ignore_index=True)

    return correlation_df

def XGBoost(X, y):
    # データを訓練用とテスト用に分割
    X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    # 訓練データをさらに訓練用と検証用に分割
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=0)

    # モデルのパラメータを設定(CPU)
    params = {
        'objective': 'multi:softmax',
        'eval_metric': 'mlogloss',
        'num_class' : 2,
        'eta': 0.1,
        'max_depth': 4,
        'seed': 0,
        'tree_method': 'gpu_hist',
        'predictor': 'gpu_predictor'
    }
    
    # データをpandas.DataFrame形式で保存
    X_train_df = pd.DataFrame(X_train, columns=column_names)
    y_train_df = pd.DataFrame(y_train, columns=column_names)

    # 訓練データと検証データをXGBoostのDMatrix形式に変換
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)

    # 訓練データと検証データのセットをリストに格納
    evals = [(dtrain, 'train'), (dval, 'eval')]

    # モデルを訓練
    bst = xgb.train(params, dtrain, num_boost_round=10000, evals=evals, early_stopping_rounds=100)

    # テストデータをDMatrix形式に変換
    dtest = xgb.DMatrix(X_test)

    # 訓練データで予測
    y_train_pred = bst.predict(dtrain)

    # テストデータで予測
    y_pred = bst.predict(dtest)

    # 評価
    train_accuracy = accuracy_score(y_train, y_train_pred.round())
    print(f"Training Accuracy: {train_accuracy*100:.2f}%")

    # 評価
    test_accuracy = accuracy_score(y_test, y_pred.round())
    print(f"Test Accuracy: {test_accuracy*100:.2f}%")
        
    return X_train_df, y_train_df, bst

def normalize_per_state(df, start, end):
    scaler = StandardScaler()
    df.iloc[start:end, :] = scaler.fit_transform(df.iloc[start:end, :])
    return df

# %%
raw = 1 #rawデータならば１、Bandなら０,

# 1秒ごとのデータに分割
n_samples_per_second = 256  # 256Hzのサンプリングレート
total_seconds = 10  # 全体の秒数

# データの読み込み
if(raw):
    df = pd.read_csv('Raw.csv')
    #df = pd.read_csv('Raw_ICA.csv')
else:
    df = pd.read_csv('Band.csv')
    #df = pd.read_csv('emotion.csv')

# チャンネルごとに正規化
scaler = StandardScaler()
for column in df.columns[:-1]:  # 'State'列を除くすべての列
    df[column] = scaler.fit_transform(df[column].values.reshape(-1, 1))

# %%
# Hzごと
# 特徴量と目標変数を抽出する
X = df.drop('State', axis=1)  # 'State'以外の列すべてを特徴量とします
y = df['State']  # 'State'を目標変数とします

# 列名のリストを定義
column_names = ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']

#XGBoost
X_train_df, y_train_df, bst = XGBoost(X, y)
# Out:
# [0]	train-mlogloss:0.62756	eval-mlogloss:0.63232
# [49]	train-mlogloss:0.05748	eval-mlogloss:0.10716
# [50]	train-mlogloss:0.05606	eval-mlogloss:0.10566
# [51]	train-mlogloss:0.05457	eval-mlogloss:0.10368
# [52]	train-mlogloss:0.05221	eval-mlogloss:0.10124
# [53]	train-mlogloss:0.05014	eval-mlogloss:0.09927
# [54]	train-mlogloss:0.04904	eval-mlogloss:0.09736
# [55]	train-mlogloss:0.04722	eval-mlogloss:0.09487
# [56]	train-mlogloss:0.04561	eval-mlogloss:0.09359
# [57]	train-mlogloss:0.04416	eval-mlogloss:0.09277
# [58]	train-mlogloss:0.04317	eval-mlogloss:0.09096
# [59]	train-mlogloss:0.04201	eval-mlogloss:0.08951
# [60]	train-mlogloss:0.04062	eval-mlogloss:0.08735
# [61]	train-mlogloss:0.03963	eval-mlogloss:0.08585
# [62]	train-mlogloss:0.03887	eval-mlogloss:0.08499
# [63]	train-mlogloss:0.03764	eval-mlogloss:0.08439
# [64]	train-mlogloss:0.03607	eval-mlogloss:0.08200
# [65]	train-mlogloss:0.03502	eval-mlogloss:0.08165
# [66]	train-mlogloss:0.03382	eval-mlogloss:0.08034
# [67]	train-mlogloss:0.03281	eval-mlogloss:0.07910
# [68]	train-mlogloss:0.03157	eval-mlogloss:0.07740
# [69]	train-mlogloss:0.03048	eval-mlogloss:0.07603
# [70]	train-mlogloss:0.02981	eval-mlogloss:0.07489
# [71]	train-mlogloss:0.02847	eval-mlogloss:0.07290
# [72]	train-mlogloss:0.02729	eval-mlogloss:0.07159
# [73]	train-mlogloss:0.02644	eval-mlogloss:0.07035
# [74]	train-mlogloss:0.02547	eval-mlogloss:0.06927
# [75]	train-mlogloss:0.02480	eval-mlogloss:0.06801
# [76]	train-mlogloss:0.02402	eval-mlogloss:0.06715
# [77]	train-mlogloss:0.02321	eval-mlogloss:0.06569
# [78]	train-mlogloss:0.02268	eval-mlogloss:0.06482
# [79]	train-mlogloss:0.02211	eval-mlogloss:0.06422
# [80]	train-mlogloss:0.02174	eval-mlogloss:0.06427
# [81]	train-mlogloss:0.02094	eval-mlogloss:0.06310
# [82]	train-mlogloss:0.02046	eval-mlogloss:0.06283
# [83]	train-mlogloss:0.01973	eval-mlogloss:0.06155
# [84]	train-mlogloss:0.01924	eval-mlogloss:0.06116
# [85]	train-mlogloss:0.01879	eval-mlogloss:0.06046
# [86]	train-mlogloss:0.01850	eval-mlogloss:0.06022
# [87]	train-mlogloss:0.01799	eval-mlogloss:0.05938
# [88]	train-mlogloss:0.01749	eval-mlogloss:0.05885
# [89]	train-mlogloss:0.01708	eval-mlogloss:0.05795
# [90]	train-mlogloss:0.01654	eval-mlogloss:0.05683
# [91]	train-mlogloss:0.01611	eval-mlogloss:0.05621
# [92]	train-mlogloss:0.01568	eval-mlogloss:0.05574
# [93]	train-mlogloss:0.01532	eval-mlogloss:0.05568
# [94]	train-mlogloss:0.01491	eval-mlogloss:0.05491
# [95]	train-mlogloss:0.01470	eval-mlogloss:0.05463
# [96]	train-mlogloss:0.01443	eval-mlogloss:0.05391
# [673]	train-mlogloss:0.00115	eval-mlogloss:0.02567
# [674]	train-mlogloss:0.00115	eval-mlogloss:0.02572
# [675]	train-mlogloss:0.00115	eval-mlogloss:0.02577
# [676]	train-mlogloss:0.00115	eval-mlogloss:0.02571
# [677]	train-mlogloss:0.00115	eval-mlogloss:0.02572
# [678]	train-mlogloss:0.00114	eval-mlogloss:0.02575
# [679]	train-mlogloss:0.00114	eval-mlogloss:0.02572
# [680]	train-mlogloss:0.00114	eval-mlogloss:0.02572
# [681]	train-mlogloss:0.00114	eval-mlogloss:0.02569
# [682]	train-mlogloss:0.00114	eval-mlogloss:0.02572
# [683]	train-mlogloss:0.00114	eval-mlogloss:0.02563
# [684]	train-mlogloss:0.00114	eval-mlogloss:0.02561
# [685]	train-mlogloss:0.00114	eval-mlogloss:0.02564
# [686]	train-mlogloss:0.00114	eval-mlogloss:0.02563
# [687]	train-mlogloss:0.00114	eval-mlogloss:0.02564
# [688]	train-mlogloss:0.00114	eval-mlogloss:0.02560
# [689]	train-mlogloss:0.00114	eval-mlogloss:0.02560
# [690]	train-mlogloss:0.00114	eval-mlogloss:0.02559
# [691]	train-mlogloss:0.00114	eval-mlogloss:0.02561
# [692]	train-mlogloss:0.00114	eval-mlogloss:0.02563
# [693]	train-mlogloss:0.00114	eval-mlogloss:0.02566
# [694]	train-mlogloss:0.00114	eval-mlogloss:0.02563
# [695]	train-mlogloss:0.00114	eval-mlogloss:0.02568
# [696]	train-mlogloss:0.00113	eval-mlogloss:0.02569
# [697]	train-mlogloss:0.00113	eval-mlogloss:0.02566
# [698]	train-mlogloss:0.00113	eval-mlogloss:0.02571
# [699]	train-mlogloss:0.00113	eval-mlogloss:0.02574
# [700]	train-mlogloss:0.00113	eval-mlogloss:0.02569
# [701]	train-mlogloss:0.00113	eval-mlogloss:0.02568
# [702]	train-mlogloss:0.00113	eval-mlogloss:0.02567
# [703]	train-mlogloss:0.00113	eval-mlogloss:0.02570
# [704]	train-mlogloss:0.00113	eval-mlogloss:0.02573
# [705]	train-mlogloss:0.00113	eval-mlogloss:0.02571
# [706]	train-mlogloss:0.00113	eval-mlogloss:0.02567
# [707]	train-mlogloss:0.00113	eval-mlogloss:0.02569
# [708]	train-mlogloss:0.00113	eval-mlogloss:0.02567
# [709]	train-mlogloss:0.00113	eval-mlogloss:0.02567
# [710]	train-mlogloss:0.00113	eval-mlogloss:0.02564
# [711]	train-mlogloss:0.00113	eval-mlogloss:0.02569
# [712]	train-mlogloss:0.00113	eval-mlogloss:0.02567
# [713]	train-mlogloss:0.00113	eval-mlogloss:0.02572
# [714]	train-mlogloss:0.00113	eval-mlogloss:0.02563
# [715]	train-mlogloss:0.00113	eval-mlogloss:0.02564
# [716]	train-mlogloss:0.00112	eval-mlogloss:0.02559
# [717]	train-mlogloss:0.00112	eval-mlogloss:0.02562
# [718]	train-mlogloss:0.00112	eval-mlogloss:0.02560
# [719]	train-mlogloss:0.00112	eval-mlogloss:0.02559
# [720]	train-mlogloss:0.00112	eval-mlogloss:0.02556
# [721]	train-mlogloss:0.00112	eval-mlogloss:0.02561
# [722]	train-mlogloss:0.00112	eval-mlogloss:0.02563
# [723]	train-mlogloss:0.00112	eval-mlogloss:0.02559
# [724]	train-mlogloss:0.00112	eval-mlogloss:0.02564
# [725]	train-mlogloss:0.00112	eval-mlogloss:0.02558
# [726]	train-mlogloss:0.00112	eval-mlogloss:0.02559
# [727]	train-mlogloss:0.00112	eval-mlogloss:0.02557
# [728]	train-mlogloss:0.00112	eval-mlogloss:0.02552
# [729]	train-mlogloss:0.00112	eval-mlogloss:0.02557
# [730]	train-mlogloss:0.00112	eval-mlogloss:0.02562
# [731]	train-mlogloss:0.00112	eval-mlogloss:0.02559
# [732]	train-mlogloss:0.00112	eval-mlogloss:0.02561
# [733]	train-mlogloss:0.00112	eval-mlogloss:0.02560
# [734]	train-mlogloss:0.00112	eval-mlogloss:0.02561
# [735]	train-mlogloss:0.00111	eval-mlogloss:0.02560
# [736]	train-mlogloss:0.00111	eval-mlogloss:0.02564
# [737]	train-mlogloss:0.00111	eval-mlogloss:0.02566
# [738]	train-mlogloss:0.00111	eval-mlogloss:0.02562
# [739]	train-mlogloss:0.00111	eval-mlogloss:0.02567
# [740]	train-mlogloss:0.00111	eval-mlogloss:0.02565
# [741]	train-mlogloss:0.00111	eval-mlogloss:0.02563
# [742]	train-mlogloss:0.00111	eval-mlogloss:0.02564
# [743]	train-mlogloss:0.00111	eval-mlogloss:0.02561
# [744]	train-mlogloss:0.00111	eval-mlogloss:0.02561
# [745]	train-mlogloss:0.00111	eval-mlogloss:0.02565
# [746]	train-mlogloss:0.00111	eval-mlogloss:0.02561
# [747]	train-mlogloss:0.00111	eval-mlogloss:0.02562
# [748]	train-mlogloss:0.00111	eval-mlogloss:0.02560
# [749]	train-mlogloss:0.00111	eval-mlogloss:0.02562
# [750]	train-mlogloss:0.00111	eval-mlogloss:0.02559
# [751]	train-mlogloss:0.00111	eval-mlogloss:0.02560
# [752]	train-mlogloss:0.00111	eval-mlogloss:0.02559
# [753]	train-mlogloss:0.00111	eval-mlogloss:0.02558
# [754]	train-mlogloss:0.00111	eval-mlogloss:0.02561
# [755]	train-mlogloss:0.00111	eval-mlogloss:0.02560
# [756]	train-mlogloss:0.00111	eval-mlogloss:0.02561
# [757]	train-mlogloss:0.00111	eval-mlogloss:0.02559
# [758]	train-mlogloss:0.00111	eval-mlogloss:0.02561
# [759]	train-mlogloss:0.00110	eval-mlogloss:0.02557
# [760]	train-mlogloss:0.00110	eval-mlogloss:0.02556
# [761]	train-mlogloss:0.00110	eval-mlogloss:0.02557
# [762]	train-mlogloss:0.00110	eval-mlogloss:0.02556
# [763]	train-mlogloss:0.00110	eval-mlogloss:0.02560
# [764]	train-mlogloss:0.00110	eval-mlogloss:0.02564
# [765]	train-mlogloss:0.00110	eval-mlogloss:0.02556
# [766]	train-mlogloss:0.00110	eval-mlogloss:0.02556
# [767]	train-mlogloss:0.00110	eval-mlogloss:0.02555
# [768]	train-mlogloss:0.00110	eval-mlogloss:0.02552
# [769]	train-mlogloss:0.00110	eval-mlogloss:0.02557
# [770]	train-mlogloss:0.00110	eval-mlogloss:0.02554
# [771]	train-mlogloss:0.00110	eval-mlogloss:0.02554
# [772]	train-mlogloss:0.00110	eval-mlogloss:0.02557
# [773]	train-mlogloss:0.00110	eval-mlogloss:0.02553
# [774]	train-mlogloss:0.00110	eval-mlogloss:0.02559
# [775]	train-mlogloss:0.00110	eval-mlogloss:0.02561
# [776]	train-mlogloss:0.00110	eval-mlogloss:0.02559
# [777]	train-mlogloss:0.00110	eval-mlogloss:0.02559
# [778]	train-mlogloss:0.00110	eval-mlogloss:0.02564
# [779]	train-mlogloss:0.00110	eval-mlogloss:0.02563
# [780]	train-mlogloss:0.00110	eval-mlogloss:0.02568
# [781]	train-mlogloss:0.00110	eval-mlogloss:0.02564
# [782]	train-mlogloss:0.00109	eval-mlogloss:0.02567
# [783]	train-mlogloss:0.00109	eval-mlogloss:0.02566
# [784]	train-mlogloss:0.00109	eval-mlogloss:0.02566
# [785]	train-mlogloss:0.00109	eval-mlogloss:0.02563
# [786]	train-mlogloss:0.00109	eval-mlogloss:0.02559
# [787]	train-mlogloss:0.00109	eval-mlogloss:0.02564
# [788]	train-mlogloss:0.00109	eval-mlogloss:0.02560
# [789]	train-mlogloss:0.00109	eval-mlogloss:0.02564
# [790]	train-mlogloss:0.00109	eval-mlogloss:0.02566
# [791]	train-mlogloss:0.00109	eval-mlogloss:0.02565
# [792]	train-mlogloss:0.00109	eval-mlogloss:0.02563
# [793]	train-mlogloss:0.00109	eval-mlogloss:0.02565
# [794]	train-mlogloss:0.00109	eval-mlogloss:0.02563
# [795]	train-mlogloss:0.00109	eval-mlogloss:0.02565
# [796]	train-mlogloss:0.00109	eval-mlogloss:0.02562
# [797]	train-mlogloss:0.00109	eval-mlogloss:0.02563
# [798]	train-mlogloss:0.00109	eval-mlogloss:0.02560
# [799]	train-mlogloss:0.00109	eval-mlogloss:0.02562
# [800]	train-mlogloss:0.00109	eval-mlogloss:0.02564
# [801]	train-mlogloss:0.00109	eval-mlogloss:0.02563
# [802]	train-mlogloss:0.00109	eval-mlogloss:0.02555
# [803]	train-mlogloss:0.00109	eval-mlogloss:0.02559
# [804]	train-mlogloss:0.00109	eval-mlogloss:0.02557
# [805]	train-mlogloss:0.00109	eval-mlogloss:0.02556
# [806]	train-mlogloss:0.00109	eval-mlogloss:0.02558
# [807]	train-mlogloss:0.00108	eval-mlogloss:0.02557
# [808]	train-mlogloss:0.00108	eval-mlogloss:0.02560
# [809]	train-mlogloss:0.00108	eval-mlogloss:0.02558
# [810]	train-mlogloss:0.00108	eval-mlogloss:0.02558
# [811]	train-mlogloss:0.00108	eval-mlogloss:0.02554
# [812]	train-mlogloss:0.00108	eval-mlogloss:0.02553
# [813]	train-mlogloss:0.00108	eval-mlogloss:0.02557
# [814]	train-mlogloss:0.00108	eval-mlogloss:0.02554
# [815]	train-mlogloss:0.00108	eval-mlogloss:0.02556
# [816]	train-mlogloss:0.00108	eval-mlogloss:0.02555
# [817]	train-mlogloss:0.00108	eval-mlogloss:0.02559
# [818]	train-mlogloss:0.00108	eval-mlogloss:0.02558
# [819]	train-mlogloss:0.00108	eval-mlogloss:0.02560
# [820]	train-mlogloss:0.00108	eval-mlogloss:0.02558
# [821]	train-mlogloss:0.00108	eval-mlogloss:0.02560
# [822]	train-mlogloss:0.00108	eval-mlogloss:0.02558
# [823]	train-mlogloss:0.00108	eval-mlogloss:0.02560
# [824]	train-mlogloss:0.00108	eval-mlogloss:0.02557
# [825]	train-mlogloss:0.00108	eval-mlogloss:0.02557
# [826]	train-mlogloss:0.00108	eval-mlogloss:0.02562
# [827]	train-mlogloss:0.00108	eval-mlogloss:0.02561
# [828]	train-mlogloss:0.00108	eval-mlogloss:0.02560
# Training Accuracy: 100.00%
# Test Accuracy: 99.22%

# %%
explainer = shap.TreeExplainer(bst)
shap_values = explainer.shap_values(X_train_df,y_train_df)

shap.summary_plot(shap_values, X_train_df)

# %%
# SHAP値をプロット
shap.summary_plot(shap_values[0], X_train_df, max_display=X_train_df.shape[1])
#各ｃｈの電圧値とSHAP値の線形グラフ
shap.dependence_plot("O2", shap_values[0], X_train_df)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
# SHAP値をプロット
shap.summary_plot(shap_values[1], X_train_df, max_display=X_train_df.shape[1])
#各ｃｈの電圧値とSHAP値の線形グラフ
shap.dependence_plot("O2", shap_values[1], X_train_df)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
num_classes = 2  # クラス数を設定
correlation_df = calculate_correlations(shap_values, X_train_df, column_names, num_classes).T
correlation_df
# Out:
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                      0         1         2         3         4         5   \
# feature             AF3        F7        F3       FC5        T7        P7
# correlation_0 -0.909493  0.717904  0.665764 -0.396998  0.949571 -0.848424
# correlation_1  0.909104 -0.717904 -0.665765  0.394231 -0.949571  0.848424
#
#                      6         7         8         9         10        11  \
# feature              O1        O2        P8        T8       FC6        F4
# correlation_0 -0.917555  0.770569  0.953559 -0.909332  0.918027   0.87579
# correlation_1  0.918278 -0.770569 -0.953559  0.909084 -0.918369 -0.875854
#
#                      12        13
# feature              F8       AF4
# correlation_0 -0.676069  0.558621
# correlation_1  0.676069 -0.558621

# %% [raw]
# """
# #１秒ごとに分割
# # ラベルの作成（5秒閉じ、5秒開け）
# labels_close = [0] * 5 *64
# labels_open = [1] * 5 * 64
# labels = labels_close + labels_open
#
# #labels = df.iloc[:, -1]
#
# #14chデータ
# n_samples_per_second = 4
# total_seconds = 10  # 全体の秒数
# #total_seconds = 3242  # 全体の秒数
#
# # データとラベルを1秒ごとに分割
# #X = np.array([df.iloc[i*n_samples_per_second:(i+1)*n_samples_per_second, :-1].values for i in range(total_seconds)])
#
# X = np.array([df.iloc[i*n_samples_per_second:(i+1)*n_samples_per_second, :-1].values for i in range(total_seconds*64)])
# #labels = np.array([stats.mode(y[i*n_samples_per_second:(i+1)*n_samples_per_second])[0][0] for i in range(total_seconds*64)])
#
#
# # 1秒ごとのデータの平均を取得
# X = X.mean(axis=1)
#
# #XGBoost
# XGBoost(X, labels)
#
# #plot
# #plot_importance(raw, model1)
#
# """
