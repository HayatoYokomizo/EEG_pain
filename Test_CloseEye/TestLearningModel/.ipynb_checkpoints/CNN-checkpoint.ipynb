# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dense
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import os
from scipy import stats
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]= "true"
# Out:
# 2023-05-30 16:08:54.218141: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def create_model():
    model = Sequential()
    model.add(tf.keras.layers.Conv1D(256, 5, padding="same", activation="relu", input_shape=(14,256))) # tf.keras.layers.Conv1D 
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense (512,activation="relu"))
    model.add(tf.keras.layers.Dense (4,activation="softmax"))
    #model.add(tf.keras.layers.Dense (2,activation="softmax"))
    
    model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), optimizer="adam", metrics=['accuracy'])  # 損失関数はbinary_crossentropy
    return model

# %%
# データの読み込み
#df = pd.read_csv('raw.csv')
df = pd.read_csv('emotion.csv')

# 1秒ごとのデータに分割
ch_count = 14

n_samples_per_second = 256  # 256Hzのサンプリングレート

#total_seconds = 10  # 全体の秒数
total_seconds = 3242  # 全体の秒数

# ラベルの作成（5秒閉じ、5秒開け）
#labels_close = [0] * 5 
#labels_open = [1] * 5 
#labels = labels_close + labels_open
labels = np.array([df["State"][i*256] for i in range(total_seconds)])
labels = to_categorical(labels)

# データとラベルを1秒ごとに分割
X = np.array([df.iloc[i*n_samples_per_second:(i+1)*n_samples_per_second, :-1].values for i in range(total_seconds)])

X = X.transpose(2,0,1)
for i in range(ch_count):
    scaler = StandardScaler()
    X[i] = scaler.fit_transform(X[i])
X = X.transpose(1,0,2)

# 学習用とテスト用に分割
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=0)

# モデル作成
model = create_model()

# 学習
model.fit(X_train, y_train, epochs=100, batch_size=16, verbose=1, validation_data = [X_val, y_val], callbacks=[tf.keras.callbacks.EarlyStopping(patience=20)])

# 訓練データに対する評価
train_scores = model.evaluate(X_train, y_train, verbose=1)
print(f"Training Accuracy: {train_scores[1]*100}")

# テストデータに対する評価
test_scores = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Accuracy: {test_scores[1]*100}")
# Out:
# Epoch 1/100
# 122/122 [==============================] - 1s 3ms/step - loss: 1.5599 - accuracy: 0.3246 - val_loss: 1.3638 - val_accuracy: 0.3451
# Epoch 2/100
# 122/122 [==============================] - 0s 2ms/step - loss: 1.3073 - accuracy: 0.3981 - val_loss: 1.3815 - val_accuracy: 0.3436
# Epoch 3/100
# 122/122 [==============================] - 0s 2ms/step - loss: 1.2614 - accuracy: 0.4203 - val_loss: 1.3892 - val_accuracy: 0.3821
# Epoch 4/100
# 122/122 [==============================] - 0s 3ms/step - loss: 1.2043 - accuracy: 0.4460 - val_loss: 1.5568 - val_accuracy: 0.3606
# Epoch 5/100
# 122/122 [==============================] - 0s 2ms/step - loss: 1.1434 - accuracy: 0.4866 - val_loss: 1.4219 - val_accuracy: 0.3683
# Epoch 6/100
# 122/122 [==============================] - 0s 2ms/step - loss: 1.0682 - accuracy: 0.5324 - val_loss: 1.5834 - val_accuracy: 0.3174
# Epoch 7/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.9824 - accuracy: 0.5828 - val_loss: 1.5335 - val_accuracy: 0.3529
# Epoch 8/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.8996 - accuracy: 0.6307 - val_loss: 1.7401 - val_accuracy: 0.3421
# Epoch 9/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.7652 - accuracy: 0.6965 - val_loss: 1.8599 - val_accuracy: 0.3451
# Epoch 10/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.6918 - accuracy: 0.7227 - val_loss: 2.1290 - val_accuracy: 0.3405
# Epoch 11/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.5400 - accuracy: 0.7989 - val_loss: 2.2589 - val_accuracy: 0.3297
# Epoch 12/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.4790 - accuracy: 0.8323 - val_loss: 2.3712 - val_accuracy: 0.3205
# Epoch 13/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.3236 - accuracy: 0.8853 - val_loss: 2.8996 - val_accuracy: 0.3390
# Epoch 14/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.3591 - accuracy: 0.8724 - val_loss: 3.2204 - val_accuracy: 0.3205
# Epoch 15/100
# 122/122 [==============================] - 0s 4ms/step - loss: 0.2203 - accuracy: 0.9275 - val_loss: 3.4162 - val_accuracy: 0.3344
# Epoch 16/100
# 122/122 [==============================] - 0s 4ms/step - loss: 0.1368 - accuracy: 0.9604 - val_loss: 3.5547 - val_accuracy: 0.3436
# Epoch 17/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2069 - accuracy: 0.9285 - val_loss: 4.3123 - val_accuracy: 0.3159
# Epoch 18/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.4256 - accuracy: 0.8668 - val_loss: 3.9366 - val_accuracy: 0.3066
# Epoch 19/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.4481 - accuracy: 0.8513 - val_loss: 3.8535 - val_accuracy: 0.3174
# Epoch 20/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.9398 - val_loss: 3.9088 - val_accuracy: 0.3082
# Epoch 21/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9825 - val_loss: 4.3366 - val_accuracy: 0.3374
# 61/61 [==============================] - 0s 1ms/step - loss: 0.0287 - accuracy: 0.9923
# Training Accuracy: 99.22839403152466
# 21/21 [==============================] - 0s 1ms/step - loss: 3.9723 - accuracy: 0.3390
# Test Accuracy: 33.898305892944336

# %%
def create_model():
    model = Sequential()
    model.add(tf.keras.layers.Dense(64, activation="relu", input_shape=(14,)))
    model.add(tf.keras.layers.Dense(32,activation="relu"))
    model.add(tf.keras.layers.Dense(4,activation="softmax"))
    
    model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), optimizer="adam", metrics=['accuracy'])  # 損失関数はbinary_crossentropy
    return model

# %%
df = pd.read_csv('emotion.csv')
y = df["State"]
df = df.drop(["State"],axis=1)

# %%
X = np.array(df).transpose(1,0).reshape(14,-1,1)
for i in range(ch_count):
    scaler = StandardScaler()
    X[i] = scaler.fit_transform(X[i].reshape(-1,1))
X = X.transpose(1,0,2).reshape(-1,14)

y = to_categorical(y)
# 学習用とテスト用に分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=0)

# モデル作成
model = create_model()

# 学習
model.fit(X_train, y_train, epochs=10000, batch_size=64, verbose=1, validation_data = [X_val, y_val], callbacks=[tf.keras.callbacks.EarlyStopping(patience=50)])

# 訓練データに対する評価
train_scores = model.evaluate(X_train, y_train, verbose=1)
print(f"Training Accuracy: {train_scores[1]*100}")

# テストデータに対する評価
test_scores = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Accuracy:
10000
# 7782/7782 [==============================] - 14s 2ms/step - loss: 1.1025 - accuracy: 0.4987 - val_loss: 1.1145 - val_accuracy: 0.4928
# Epoch 81/10000
# 7782/7782 [==============================] - 14s 2ms/step - loss: 1.1024 - accuracy: 0.4986 - val_loss: 1.1102 - val_accuracy: 0.4953
# Epoch 82/10000
# 7782/7782 [==============================] - 17s 2ms/step - loss: 1.1026 - accuracy: 0.4983 - val_loss: 1.1109 - val_accuracy: 0.4940
# Epoch 83/10000
# 7782/7782 [==============================] - 18s 2ms/step - loss: 1.1021 - accuracy: 0.4991 - val_loss: 1.1132 - val_accuracy: 0.4923
# Epoch 84/10000
# 7782/7782 [==============================] - 16s 2ms/step - loss: 1.1021 - accuracy: 0.4991 - val_loss: 1.1118 - val_accuracy: 0.4938
# Epoch 85/10000
# 7782/7782 [==============================] - 15s 2ms/step - loss: 1.1020 - accuracy: 0.4989 - val_loss: 1.1111 - val_accuracy: 0.4938
# Epoch 86/10000
# 7782/7782 [==============================] - 16s 2ms/step - loss: 1.1021 - accuracy: 0.4987 - val_loss: 1.1105 - val_accuracy: 0.4948
# Epoch 87/10000
# 7782/7782 [==============================] - 16s 2ms/step - loss: 1.1020 - accuracy: 0.4995 - val_loss: 1.1100 - val_accuracy: 0.4958
# Epoch 88/10000
# 7782/7782 [==============================] - 15s 2ms/step - loss: 1.1018 - accuracy: 0.4991 - val_loss: 1.1099 - val_accuracy: 0.4944
# Epoch 89/10000
# 7782/7782 [==============================] - 16s 2ms/step - loss: 1.1016 - accuracy: 0.4990 - val_loss: 1.1104 - val_accuracy: 0.4938
# Epoch 90/10000
# 7782/7782 [==============================] - 17s 2ms/step - loss: 1.1017 - accuracy: 0.4990 - val_loss: 1.1139 - val_accuracy: 0.4928
# Epoch 91/10000
# 7782/7782 [==============================] - 17s 2ms/step - loss: 1.1015 - accuracy: 0.4989 - val_loss: 1.1090 - val_accuracy: 0.4951
# Epoch 92/10000
# 7782/7782 [==============================] - 17s 2ms/step - loss: 1.1015 - accuracy: 0.4993 - val_loss: 1.1119 - val_accuracy: 0.4945
# Epoch 93/10000
# 7782/7782 [==============================] - 17s 2ms/step - loss: 1.1013 - accuracy: 0.4992 - val_loss: 1.1121 - val_accuracy: 0.4923
# Epoch 94/10000
# 7782/7782 [==============================] - 16s 2ms/step - loss: 1.1012 - accuracy: 0.4994 - val_loss: 1.1109 - val_accuracy: 0.4944
# Epoch 95/10000
# 7782/7782 [==============================] - 15s 2ms/step - loss: 1.1010 - accuracy: 0.4993 - val_loss: 1.1122 - val_accuracy: 0.4935
# Epoch 96/10000
# 7782/7782 [==============================] - 17s 2ms/step - loss: 1.1012 - accuracy: 0.4997 - val_loss: 1.1088 - val_accuracy: 0.4948
# Epoch 97/10000
# 7782/7782 [==============================] - 16s 2ms/step - loss: 1.1009 - accuracy: 0.4992 - val_loss: 1.1100 - val_accuracy: 0.4949
# Epoch 98/10000
# 7782/7782 [==============================] - 15s 2ms/step - loss: 1.1011 - accuracy: 0.4993 - val_loss: 1.1095 - val_accuracy: 0.4955
# Epoch 99/10000
# 7782/7782 [==============================] - 16s 2ms/step - loss: 1.1006 - accuracy: 0.4992 - val_loss: 1.1108 - val_accuracy: 0.4935
# Epoch 100/10000
# 7782/7782 [==============================] - 16s 2ms/step - loss: 1.1009 - accuracy: 0.4993 - val_loss: 1.1092 - val_accuracy: 0.4957
# Epoch 101/10000
# 7782/7782 [==============================] - 15s 2ms/step - loss: 1.1009 - accuracy: 0.4996 - val_loss: 1.1101 - val_accuracy: 0.4950
# Epoch 102/10000
# 7782/7782 [==============================] - 18s 2ms/step - loss: 1.1009 - accuracy: 0.4993 - val_loss: 1.1114 - val_accuracy: 0.4950
# Epoch 103/10000
# 7782/7782 [==============================] - 16s 2ms/step - loss: 1.1007 - accuracy: 0.4992 - val_loss: 1.1123 - val_accuracy: 0.4938
# Epoch 104/10000
# 7782/7782 [==============================] - 15s 2ms/step - loss: 1.1006 - accuracy: 0.4996 - val_loss: 1.1102 - val_accuracy: 0.4950
# Epoch 105/10000
# 7122/7782 [==========================>...] - ETA: 1s - loss: 1.1008 - accuracy: 0.4994
